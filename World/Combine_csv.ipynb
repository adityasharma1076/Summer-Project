# %%
import os
import glob
import pandas as pd
os.chdir("C:\\Users\drago\Documents\GitHub\Summer-Project\World")

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
# %run ./Times_of_India_World.ipynb
# %run ./Hindustan_times_World.ipynb
# %run ./Indian_express_World.ipynb
# %run ./India_Today_World.ipynb
#%run ./India_Times_World.ipynb
# %run ./CNN_World.ipynb

# %%
extension = 'csv'
string = 'CSV/'+Today_date+'/*.{}'
all_filenames = [i for i in glob.glob(string.format(extension))]

# %%
all_filenames
# Out:
# ['CSV/2019-06-12\\CNN_world-2019-06-12.csv',
#  'CSV/2019-06-12\\HT_world-2019-06-12.csv',
#  'CSV/2019-06-12\\IE_world-2019-06-12.csv',
#  'CSV/2019-06-12\\IT_world-2019-06-12.csv',
#  'CSV/2019-06-12\\TOI_world-2019-06-12.csv']

# %%
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])

# %%
outname = 'combined_world-'+str(Today_date)+'.csv'
root = 'Combined CSV/'
if not os.path.exists(root):
    os.mkdir(root)
#date_today= Today_date +'\ '
outdir=root
if not os.path.exists(outdir):
    os.mkdir(outdir)
fullname = os.path.join(outdir, outname)

# %%
combined_csv.to_csv(fullname, index=False, encoding='utf-8')

# %%
df = pd.read_csv(fullname)

# %%
df['Category'].value_counts()
# Out:
# us                160
# world              93
# europe             88
# china              80
# uk                 80
# middle east        66
# pakistan           50
# mad, mad world     50
# rest of world      50
# south asia         50
# africa             45
# asia               44
# australia          38
# india              35
# americas           24
# Name: Category, dtype: int64

# %%
def fix_you(x):
    
    if(x=='south asia'):
        return 'asia'
    else:
        return x
    
df['Category'] = df['Category'].apply(fix_you)

# %%
combined_csv.to_csv(fullname, index=False, encoding='utf-8')
df = pd.read_csv(fullname)

# %%
pd.read_csv(fullname)
# Out:
#              Source                                            Heading  \
# 0               CNN  America's renewable energy capacity is now gre...
# 1               CNN  Black drivers in Missouri are 91% more likely ...
# 2               CNN  Florida lawmakers want to make the Pulse night...
# 3               CNN  Estranged husband pleads not guilty in connect...
# 4               CNN  Second suspect arrested in David Ortiz shootin...
# 5               CNN  Prosecutors say his DNA was found mixed with h...
# 6               CNN  Lightning strike kills two giraffes at a popul...
# 7               CNN  Estranged husband of missing Connecticut mothe...
# 8               CNN  5 things to know for June 12: Hong Kong, campa...
# 9               CNN  Record heat for California as the West Coast h...
# 10              CNN  West Coast's triple-digit heat wave drives sta...
# 11              CNN  The shooter haunted her, until she said 'no more'
# 12              CNN  Man detained in David Ortiz's shooting is accu...
# 13              CNN  Denver Zoo shares the story of same-sex flamin...
# 14              CNN  Judge throws out lawsuit attempting to block O...
# 15              CNN  Analysis: Democrats are betting big on big pla...
# 16              CNN  Top 2020 Democrats best Trump in hypothetical ...
# 17              CNN  Pence calls US ban on flying LGBTQ flags from ...
# 18              CNN  Deepfakes are a real threat to the 2020 electi...
# 19              CNN  The American oil boom is rewriting the history...
