# %%
import os
import glob
import pandas as pd
os.chdir("C:\\Users\drago\Documents\GitHub\Summer-Project\World")

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
# %run ./Times_of_India_World.ipynb
# %run ./Hindustan_times_World.ipynb
# %run ./Indian_express_World.ipynb
# %run ./India_Today_World.ipynb
#%run ./India_Times_World.ipynb
# %run ./CNN_World.ipynb

# %%
extension = 'csv'
string = 'CSV/'+Today_date+'/*.{}'
all_filenames = [i for i in glob.glob(string.format(extension))]

# %%
all_filenames
# Out:
# ['CSV/2019-06-10\\CNN_world-2019-06-10.csv',
#  'CSV/2019-06-10\\HT_world-2019-06-10.csv',
#  'CSV/2019-06-10\\IE_world-2019-06-10.csv',
#  'CSV/2019-06-10\\IT_world-2019-06-10.csv',
#  'CSV/2019-06-10\\TOI_world-2019-06-10.csv']

# %%
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])

# %%
outname ='combined_world-'+str(Today_date)+'.csv'
x=r"C:\Users\drago\Documents\GitHub\Summer-Project\World\Combined CSV\ "
if not os.path.exists(x[:-1]):
    os.mkdir(x[:-1])
#date_today= Today_date +'\ '
outdir=x[:-1]
if not os.path.exists(outdir):
    os.mkdir(outdir)
fullname = os.path.join(outdir, outname)

# %%
combined_csv.to_csv(fullname, index=False, encoding='utf-8')

# %%
df = pd.read_csv(fullname)

# %%
df['Category'].value_counts()
# Out:
# us                162
# world              93
# europe             88
# china              81
# uk                 80
# middle east        66
# rest of world      50
# mad, mad world     50
# south asia         50
# pakistan           50
# africa             45
# asia               44
# australia          38
# india              35
# americas           24
# Name: Category, dtype: int64

# %%
def fix_you(x):
    
    if(x=='south asia'):
        return 'asia'
    else:
        return x
    
df['Category'] = df['Category'].apply(fix_you)

# %%
combined_csv.to_csv(fullname, index=False, encoding='utf-8')
df = pd.read_csv(fullname)

# %%
pd.read_csv(fullname)
# Out:
#              Source                                            Heading  \
# 0               CNN  Army vet dies in police custody. His body was ...
# 1               CNN  Police look for mother after newborn found in ...
# 2               CNN  Man in custody in connection with suspected se...
# 3               CNN  Plane crash kills both people onboard. Dog sur...
# 4               CNN  Michigan hotel offers free stay to anyone trav...
# 5               CNN  3 people trapped in car die after vehicle hits...
# 6               CNN  At least 1 person is dead and 6 others injured...
# 7               CNN  Hundreds of firefighters are battling blazes o...
# 8               CNN               See moment crane collapses in Dallas
# 9               CNN  How a message of acceptance from rural Oklahom...
# 10              CNN  As communities celebrate Pride month, Detroit ...
# 11              CNN  Detroit police arrest teen in deaths of 3 LGBT...
# ...
