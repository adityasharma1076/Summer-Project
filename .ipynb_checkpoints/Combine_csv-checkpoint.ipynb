# %%
import os
import glob
import pandas as pd
os.chdir("C:\\Users\drago\Documents\GitHub\Summer-Project")

# %%
# %run ./Times_of_India.ipynb
# %run ./Hindustan_times_education.ipynb
# %run ./Indian_express_education.ipynb

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
all_filenames.remove('combined_csv.csv')

# %%
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])

# %%
combined_csv.to_csv( "combined_csv-28-05-2019.csv", index=False, encoding='utf-8')

# %%
pd.read_csv('combined_csv-28-05-2019.csv')
# Out:
#             Newspaper                                            Heading  \
# 0    Hindiustan Times  MSBSHSE 12th result 2019 declared today. Check...
# 1    Hindiustan Times  Maharashtra Board Result 2019: MSBSHSE 12th re...
# 2    Hindiustan Times  TSBIE Telangana board TS inter 12th revaluatio...
# 3    Hindiustan Times  UGC to study quality of PhD thesis for doctora...
# 4    Hindiustan Times  DU Campus Prep: Hey, soon-to-be Fuchchas, read...
# 5    Hindiustan Times  DU Admission 2019: Cutoff relief for students ...
# 6    Hindiustan Times  Record 1.77 lakh students apply for degree cou...
# 7    Hindiustan Times  Kerala Plus One Result 2019 Declared: DHSE dec...
# 8    Hindiustan Times  Maharashtra Board Result 2019 Highlights: HSC ...
# 9    Hindiustan Times  MSBSHSE 12th result 2019 declared today. Check...
# 10   Hindiustan Times  TSBIE Telangana board TS inter 12th revaluatio...
# 11   Hindiustan Times  College, varsity teachers to get lessons in co...
# ...
