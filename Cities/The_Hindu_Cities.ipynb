# %%
import os
import pandas as pd
import numpy as np
import requests
import bs4

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
def record_date_time(z):
    x=str.split(z,' ')
    x[1] = fix_date(x[1])
    date =x[1]+' '+x[2]+' '+x[3]
    time= x[4] +':00'

    return date,time

# %%
def fix_date(p):
    if(p=='January'):
        return 'Jan'
    elif(p=='February'):
        return 'Feb'
    elif(p=='March'):
        return 'Mar'
    elif(p=='April'):
        return 'Apr'
    elif(p=='May'):
        return 'May'
    elif(p=='June'):
        return 'Jun'
    elif(p=='July'):
        return 'Jul'
    elif(p=='August'):
        return 'Aug'
    elif(p=='September'):
        return 'Sep'
    elif(p=='October'):
        return 'Oct'
    elif(p=='November'):
        return 'Nov'
    elif(p=='Dececmber'):
        return 'Dec'

# %%
link = 'https://www.thehindu.com/news/cities/'
res = requests.get(link)
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
scrape = soup.findAll('ul',{"class":"col-lg-2 col-md-2 col-sm-12 col-xs-12"})

# %%
for i in scrape:
    
    if (i.find('a')['href'] =='https://www.thehindu.com/news/cities/'):
        content = i
List = content.find('ul',{"class":'sub-menu'}).findAll('li')

# %%
records= []
for link in List:
    url = link.find('a')['href']
    category = link.text.lower()[2:-2] +' news'
    
    res = requests.get(url)
    soup = bs4.BeautifulSoup(res.text,'lxml')
    maincontent = soup.findAll('div',{'class':'col-lg-6 col-md-6 col-sm-6 col-xs-12'})
    
    for record in maincontent[1:]:
        
        z=record.find('h2')
        if not z:
            z=record.find('h3')
            
        URL = z.find('a')['href']
        Heading = z.text[2:-2]

        Date,Time = record_date_time(z.find('a')['title'])
        Category = category
        Source = 'The Hindu'
        records.append((Source,Heading,Category,Date,Time,URL))
        
        
    maincontent = soup.findAll('div',{'class':'Other-StoryCard'})
    
    for record in maincontent[1:]:
        
        
        z=record.find('h3')
            
        URL = z.find('a')['href']
        Heading = z.text[2:-2]

        Date,Time = record_date_time(z.find('a')['title'])
        Category = category
        Source = 'The Hindu'
        records.append((Source,Heading,Category,Date,Time,URL))

# %%
import pandas as pd
df=pd.DataFrame(records,columns=['Source','Heading','Category','Date','Time','URL'])
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#         Source                                            Heading  \
# 0    The Hindu  NGT panel on Bellandur, Varthur lakes to hold ...
# 1    The Hindu                Two documentaries on the playwright
# 2    The Hindu  A little rain is enough to inundate city’s und...
# 3    The Hindu  Expert highlights flaws in waste processing pl...
# 4    The Hindu    Farmers protest proposed amendments to land Act
# 5    The Hindu                  Taking sports beyond games period
# 6    The Hindu              Chandrayaan-2 launch on July 15: ISRO
# 7    The Hindu                Two documentaries on the playwright
# 8    The Hindu              Special teams to track down MD of IMA
# 9    The Hindu                     Woman, two children found dead
# 10   The Hindu  NGT panel on Bellandur, Varthur lakes to hold ...
# 11   The Hindu  Tears, anger, and worry as victims continue to...
# 12   The Hindu  Angry villagers set fire to temple caretaker’s...
# 13   The Hindu                         Fatal fall for housekeeper
# 14   The Hindu                             IT firm manager booked
# 15   The Hindu             37% women students in IIMB’s MBA batch
# 16   The Hindu     Over 3,000 complaints against MD of IMA Jewels
# 17   The Hindu                    Sudanese arrested by KIA police
# 18   The Hindu                         Biker run over by BMTC bus
# 19   The Hindu  Aeronautical Development Agency’s email accoun...
# 20   The Hindu    Farmers protest proposed amendments to land Act
# 21   The Hindu                  Taking sports beyond games period
# 22   The Hindu  A little rain is enough to inundate city’s und...
