# %%
import os
import glob
import pandas as pd
os.chdir("C:\\Users\drago\Documents\GitHub\Summer-Project\Entertainment")

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
#%run ./Times_of_India_education.ipynb
# %run ./Hindustan_Times_entertainment.ipynb
# %run ./Indian_express_entertainment.ipynb
# %run ./India_Today_entertainment.ipynb
# %run ./India_Times_entertainment.ipynb

# %%
extension = 'csv'
string = 'CSV/'+Today_date+'/*.{}'
all_filenames = [i for i in glob.glob(string.format(extension))]

# %%
all_filenames
# Out:
# ['CSV/2019-06-05\\HT_entertainment-2019-06-05.csv',
#  'CSV/2019-06-05\\IE_entertainment-2019-06-05.csv',
#  'CSV/2019-06-05\\InTi_entertainment-2019-06-05.csv',
#  'CSV/2019-06-05\\IT_entertainment-2019-06-05.csv']

# %%
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])

# %%
outname ='combined_education-'+str(Today_date)+'.csv'
x=r"C:\Users\drago\Documents\GitHub\Summer-Project\Entertainment\Combined CSV\ "
if not os.path.exists(x[:-1]):
    os.mkdir(x[:-1])
#date_today= Today_date +'\ '
outdir=x[:-1]
if not os.path.exists(outdir):
    os.mkdir(outdir)
fullname = os.path.join(outdir, outname)

# %%
combined_csv.to_csv(fullname, index=False, encoding='utf-8')

# %%
pd.read_csv(fullname)
# Out:
#             Newspaper                                            Heading  \
# 0    Hindiustan Times  Sonam Kapoor with husband Anand Ahuja at GQ 10...
# 1    Hindiustan Times  Saif Ali Khan and Kareena Kapoor leave for Lon...
# 2    Hindiustan Times  Bollywood stars attend prayer meet of Ajay Dev...
# 3    Hindiustan Times  Kangana, Hema Malini fly to Delhi for PM Modi’...
# 4    Hindiustan Times  Actor Dinyar Contractor, known for his roles i...
# 5    Hindiustan Times  Mira Rajput’s son Zain pinches sister Misha as...
# 6    Hindiustan Times  Katrina Kaif reveals she had one condition bef...
# 7    Hindiustan Times  Sara Ali Khan twins with mom Amrita in green a...
# 8    Hindiustan Times  Tiger Shroff, Abhishek Bachchan and other Boll...
# 9    Hindiustan Times  Black Mirror season 5 review: Twisted and terr...
# 10   Hindiustan Times  New James Bond film’s set rocked by an explosi...
# 11   Hindiustan Times  Deepika Padukone wraps up ‘most precious film’...
# ...
