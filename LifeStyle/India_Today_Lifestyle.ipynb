# %%
import requests
import bs4
import pandas as pd
import os

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
link = 'https://www.indiatoday.in/lifestyle'

# %%
res = requests.get(link)
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
content = soup.select(".itg-listing")

# %%
top_news=content[0].findAll('li')

# %%
def record_URL(x):
    y='https://www.indiatoday.in'
    url = y+x 
    return url

# %%
records=[]
for record in top_news:
    
    Heading = record.text
    URL= record_URL(record.find('a')['href'])
    Date = Today_date
    Time = Today_time
    Newspaper = 'India Today'
    records.append((Newspaper,Heading,Date,Time,URL))

# %%
section_news = soup.select(".section-ordering")

# %%
for i in section_news:
    li = i.findAll('p')
    for record in li:
        Heading = record.text
        URL= record_URL(record.find('a')['href'])
        Date = Today_date
        Time = Today_time
        Newspaper = 'India Today'
        records.append((Newspaper,Heading,Date,Time,URL))

# %%
import pandas as pd
df=pd.DataFrame(records,columns=['Newspaper','Heading','Date','Time','URL'])
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#       Newspaper                                            Heading       Date  \
# 0   India Today   Ananya Panday looks like a summer dream in fl... 2019-05-30
# 1   India Today   PM Modi swearing-in update: Mukesh Ambani wit... 2019-05-30
# 2   India Today   Taapsee Pannu flaunts washboard abs in chic f... 2019-05-30
# 3   India Today   Meghan Markle and Prince Harry spent Rs 26 cr... 2019-05-30
# 4   India Today    Let Kangana Ranaut in all-white attire teach... 2019-05-30
# 5   India Today   Janhvi Kapoor teaches how to do gym fashion r... 2019-05-30
# 6   India Today   Malaika Arora and Arbaaz Khan's girlfriend Gi... 2019-05-30
# 7   India Today   Katrina Kaif smiles for the paps in thigh-sli... 2019-05-30
# 8   India Today   Chitrangada Singh takes casual fashion to the... 2019-05-30
# 9   India Today   A weekend in the land of Bond: Bonfires and b... 2019-05-30
# 10  India Today   Shamita Shetty pairs floral mini dress with R... 2019-05-30
# 11  India Today   Tamannaah tries Ranveer Singh fashion in athl... 2019-05-30
# 12  India Today   New mom Meghan Markle will not meet Donald Tr... 2019-05-30
# 13  India Today   World's first guitar-shaped hotel all set to ... 2019-05-30
# 14  India Today   Heavily pregnant Sameera Reddy nails maternit... 2019-05-30
# 15  India Today   Sara Ali Khan goes boho chic in floral print ... 2019-05-30
# 16  India Today   Kiara Advani steps out in mini dress with Rs ... 2019-05-30
# 17  India Today   Shibani Dandekar trolled for copying Deepika ... 2019-05-30
# 18  India Today   Hina Khan on flak for her Cannes 2019 debut: ... 2019-05-30
# 19  India Today   Meghan Markle and Prince Harry spent Rs 26 cr... 2019-05-30
# 20  India Today   New mom Meghan Markle will not meet Donald Tr... 2019-05-30
# 21  India Today   World's first guitar-shaped hotel all set to ... 2019-05-30
# 22  India Today   GoAir kicks off flash sale with domestic flig... 2019-05-30
#
#      Time                                                URL
# 0   22:08  https://timesofindia.indiatimes.com/lifestyle/...
# 1   22:08  https://timesofindia.indiatimes.com/lifestyle/...
# 2   22:08  https://timesofindia.indiatimes.com/lifestyle/...
# 3   22:08  https://timesofindia.indiatimes.com/lifestyle/...
# 4   22:08  https://timesofindia.indiatimes.com/lifestyle/...
# 5   22:08  https://timesofindia.indiatimes.com/lifestyle/...
# 6   22:08  https://timesofindia.indiatimes.com/lifestyle/...
# 7   22:08  https://timesofindia.indiatimes.com/lifestyle/...
# 8   22:08  https://timesofindia.indiatimes.com/lifestyle/...
# 9   22:08  https://timesofindia.indiatimes.com/lifestyle/...
# 10  22:08  https://timesofindia.indiatimes.com/lifestyle/...
# 11  22:08  https://timesofindia.indiatimes.com/lifestyle/...
# 12  22:08  https://timesofindia.indiatimes.com/lifestyle/...
# 13  22:08  https://timesofindia.indiatimes.com/lifestyle/...
# 14  22:08  https://timesofindia.indiatimes.com/lifestyle/...
# 15  22:08  https://timesofindia.indiatimes.com/lifestyle/...
# 16  22:08  https://timesofindia.indiatimes.com/lifestyle/...
# 17  22:08  https://timesofindia.indiatimes.com/lifestyle/...
# 18  22:08  https://timesofindia.indiatimes.com/lifestyle/...
# 19  22:08  https://timesofindia.indiatimes.com/lifestyle/...
# 20  22:08  https://timesofindia.indiatimes.com/lifestyle/...
# 21  22:08  https://timesofindia.indiatimes.com/lifestyle/...
# 22  22:08  https://timesofindia.indiatimes.com/lifestyle/...

# %%
outname ='IT_Lifestyle-'+str(Today_date)+'.csv'
x=r"C:\Users\drago\Documents\GitHub\Summer-Project\Lifestyle\CSV\ "
if not os.path.exists(x[:-1]):
    os.mkdir(x[:-1])
date_today= Today_date +'\ '
outdir=x[:-1]+ date_today[:-1]
if not os.path.exists(outdir):
    os.mkdir(outdir)
fullname = os.path.join(outdir, outname)

# %%
df.to_csv(fullname,index=False,encoding='utf-8')
