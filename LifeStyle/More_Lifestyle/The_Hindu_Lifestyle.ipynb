# %%
import os
import pandas as pd
import numpy as np
import requests
import bs4

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
def record_date_time(z):
    x=str.split(z,' ')
    x[1] = fix_date(x[1])
    date =x[1]+' '+x[2]+' '+x[3]
    time= x[4] +':00'

    return date,time

# %%
def fix_date(p):
    if(p=='January'):
        return 'Jan'
    elif(p=='February'):
        return 'Feb'
    elif(p=='March'):
        return 'Mar'
    elif(p=='April'):
        return 'Apr'
    elif(p=='May'):
        return 'May'
    elif(p=='June'):
        return 'Jun'
    elif(p=='July'):
        return 'Jul'
    elif(p=='August'):
        return 'Aug'
    elif(p=='September'):
        return 'Sep'
    elif(p=='October'):
        return 'Oct'
    elif(p=='November'):
        return 'Nov'
    elif(p=='December'):
        return 'Dec'

# %%
link = 'https://www.thehindu.com/life-and-style/'
res = requests.get(link)
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
links = soup.find('nav',{'class':"navbar sub-menu-sticky hidden-xs "}).findAll('li')

# %%
records = []
for link in links:
    url = link.find('a')['href']
    category = link.text.lower()
    
    res = requests.get(url)
    soup = bs4.BeautifulSoup(res.text,'lxml')
    List = soup.findAll('div',{'class':'story-card-33'})
    for record in List:
        z=record.find('p')

        URL = z.find('a')['href']
        Heading = z.text[4:-4]

        Date,Time = record_date_time(z.find('a')['title'])
        Category = category
        Source = 'The Hindu'
        records.append((Source,Heading,Category,Date,Time,URL))


    maincontent = soup.findAll('div',{'class':'Other-StoryCard'})    
    for record in maincontent[1:30]:


        z=record.find('h3')

        URL = z.find('a')['href']
        Heading = z.text[2:-2]

        Date,Time = record_date_time(z.find('a')['title'])
        Category = category
        Source = 'The Hindu'
        records.append((Source,Heading,Category,Date,Time,URL))

# %%
import pandas as pd
df=pd.DataFrame(records,columns=['Source','Heading','Category','Date','Time','URL'])
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#         Source                                            Heading  \
# 0    The Hindu                      Hrithik Roshan workout, anyon
# 1    The Hindu  -living: the answer to shady, crowded and bank...
# 2    The Hindu                        The myriad sources of vineg
# 3    The Hindu                       Deft hands make seed jewelle
# 4    The Hindu  After a decade, black tiger shrimps stage a co...
# 5    The Hindu                    ow the heritage varieties of ri
# 6    The Hindu            How to cook breakfast in under 15 minut
# 7    The Hindu                                   What is aqua yog
# 8    The Hindu  undaylite |\n\nThis Chennai firm is raising th...
# 9    The Hindu                      en Nature warns building sect
# 10   The Hindu                                 A sustainable sale
# 11   The Hindu  School of Santhi organises open group yoga ses...
# 12   The Hindu   Akshay Narvekar talks Bombay Shirt Company’s USP
# 13   The Hindu                          Fresh air and friendships
# 14   The Hindu                             Some Kombucha, anyone?
# 15   The Hindu  Going with the gut: In Delhi’s first fully veg...
# 16   The Hindu                                       Sold on soap
# 17   The Hindu                Lounging with the angels in Bangkok
# 18   The Hindu  A peek into the shelves of United Nations Library
# 19   The Hindu              Sri Lanka is open for business, again
# 20   The Hindu  Music festival style from the MTV Movie Awards...
# 21   The Hindu                 Preparing your car for the monsoon
# 22   The Hindu  The first of the many sandwich shops on Montie...
# 23   The Hindu                                  Big and beautiful
# 24   The Hindu  Why you should read the fine print on a nutrit...
# 25   The Hindu  ‘Is it true that apple cider vinegar is good f...
# 26   The Hindu                     Carrying on the Avenger legacy
# 27   The Hindu  This mom-of-two is the country’s first civilia...
# 28   The Hindu          Streetwear in focus in Milan Fashion Week
# 29   The Hindu  Bajjis vs fish fry: Which is Chennai's favouri...
# ..         ...                                                ...
# 224  The Hindu  bout time\n\nPanerai watches: Made for the ope...
# 225  The Hindu         Don’t conform. Customise your luxury watch
# 226  The Hindu  How this 5655-carat, 1,133-gram Zambian emeral...
# 227  The Hindu       Kanakavalli: Quirky, with tradition to match
# 228  The Hindu  This Chennai firm is raising the interior prof...
# 229  The Hindu        How Swarovski is changing up the chandelier
# 230  The Hindu  Book your Maldivian island at Cheval Blanc Ran...
# 231  The Hindu  Why a Samsung 8K QLED TV is better than a partner
# 232  The Hindu          Louis XIII cognac for the modern Maharaja
# 233  The Hindu                   Lost in Loulou land, Sans Soucis
# 234  The Hindu                    Celebrity sizzle and some Fenty
