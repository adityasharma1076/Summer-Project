# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import random
import os

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
prefix_dir =r"C:\Users\drago\Documents\GitHub\Summer-Project\Lifestyle\Combined CSV\ "
suffix_dir = 'combined_lifestyle-'+Today_date+'.csv'
today_csv=prefix_dir[:-1] +suffix_dir

# %%
today_csv
# Out:
# 'C:\\Users\\drago\\Documents\\GitHub\\Summer-Project\\Lifestyle\\Combined CSV\\combined_lifestyle-2019-05-31.csv'

# %%
lifestyle = pd.read_csv(today_csv)

# %%
lifestyle
# Out:
#            Newspaper                                            Heading  \
# 0   Hindiustan Times  Boss Girl: Presenting Rhea Kapoor! Bollywood’s...
# 1   Hindiustan Times  Humour: Restaurants and their endless need for...
# 2   Hindiustan Times                    Travel: The Serbian melting pot
# 3   Hindiustan Times  The rise of the fall: Why mobile phone buyers ...
# 4   Hindiustan Times  Lady Gaga exhibits her quirky costume collecti...
# 5   Hindiustan Times       What motivates someone to spy on your phone?
# 6   Hindiustan Times  From street-side drug addicts to trained artists
# 7   Hindiustan Times  Sara Ali Khan’s white kurta is quite affordabl...
# 8   Hindiustan Times             Summer special: For the love of lychee
# 9   Hindiustan Times  Stress during pregnancy affects reproductive f...
# 10  Hindiustan Times  Harry Styles proves it’s a fashion era for men...
# 11  Hindiustan Times  Resurgent Capital: In and around Bogota, Columbia
# 12  Hindiustan Times  Priyanka Chopra, Sonam Kapoor, Dua Lipa show y...
# 13  Hindiustan Times  Deepika Padukone, Kareena Kapoor, Ananya Panda...
# 14  Hindiustan Times  Chaat is always a childhood memory — We can’t ...
# 15  Hindiustan Times                                   Not so Aam India
# 16  Hindiustan Times  Bollywood celebrity inspired beach accessories...
# 17  Hindiustan Times  Identity quest: An art fest that goes beyond t...
# 18  Hindiustan Times     How to make long distance relationships work?
# 19  Hindiustan Times   What’s hot in ice cream? A scoop on new flavours
# 20  Hindiustan Times  Fifth edition of the Fetes Galantes brings Fra...
# 21  Hindiustan Times  Jaipur Wax Museum celebrates Gayatri Devi’s 10...
# 22  Hindiustan Times          Meet India’s first male model with autism
# 23  Hindiustan Times  Largest art museum in US to showcase works of ...
# 24  Hindiustan Times  Seriously Cyrus: Is the salad worth the forbid...
# 25    Indian Express  ‘We need diversity behind the camera as well’:...
# 26    Indian Express  World No Tobacco Day 2019: Seven ways to avoid...
# 27    Indian Express  An exhibition in Mumbai highlights how a city ...
# 28    Indian Express  PM Modi takes oath in white kurta-pyjama and g...
# 29    Indian Express  Cranberries may help combat superbugs, says study
# ..               ...                                                ...
# 34    Indian Express  World No Tobacco Day 2019: How smokeless tobac...
# 35    Indian Express  When you are down in the dumps, it’s even more...
# 36    Indian Express                                  Any Dream Will Do
# 37    Indian Express                                   Designs on India
# 38    Indian Express  ‘We need diversity behind the camera as well’:...
# 39    Indian Express  Dal Raisina: All you need to know about the sp...
# 40    Indian Express  PM Modi takes oath in white kurta-pyjama and g...
# 41       India Today   Kareena Kapoor Khan is a glam goddess in plun...
# 42       India Today   Ananya Panday looks like a summer dream in fl...
# 43       India Today   PM Modi swearing-in update: Mukesh Ambani wit...
# 44       India Today   Taapsee Pannu flaunts washboard abs in chic f...
# 38    ‘We need diversity behind the camera as well’:...
# 39    Dal Raisina: All you need to know about the sp...
# 40    PM Modi takes oath in white kurta-pyjama and g...
# 41     Kareena Kapoor Khan is a glam goddess in plun...
# 42     Ananya Panday looks like a summer dream in fl...
# 43     PM Modi swearing-in update: Mukesh Ambani wit...
# 44     Taapsee Pannu flaunts washboard abs in chic f...
# 45     Meghan Markle and Prince Harry spent Rs 26 cr...
# 46      Let Kangana Ranaut in all-white attire teach...
# 47     Janhvi Kapoor teaches how to do gym fashion r...
# 48     Malaika Arora and Arbaaz Khan's girlfriend Gi...
# 49     Katrina Kaif smiles for the paps in thigh-sli...
# 50     Chitrangada Singh takes casual fashion to the...
# 51     A weekend in the land of Bond: Bonfires and b...
# 52     Shamita Shetty pairs floral mini dress with R...
# 53     Tamannaah tries Ranveer Singh fashion in athl...
# 54     New mom Meghan Markle will not meet Donald Tr...
# 55     World's first guitar-shaped hotel all set to ...
# 56     Heavily pregnant Sameera Reddy nails maternit...
# 57     Sara Ali Khan goes boho chic in floral print ...
# 58     Shibani Dandekar trolled for copying Deepika ...
# 59     Hina Khan on flak for her Cannes 2019 debut: ...
# 60     Meghan Markle and Prince Harry spent Rs 26 cr...
# 61     New mom Meghan Markle will not meet Donald Tr...
# 62     World's first guitar-shaped hotel all set to ...
# 63     GoAir kicks off flash sale with domestic flig...
# Name: Heading, Length: 64, dtype: object

# %%
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\drago\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopset = set(stopwords.words('english'))

# %% [markdown]
# ## Tokenizing and Stemming

# %%
import nltk
import re

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\drago\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")

# %%
def tokenize_and_stem(text):
   
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []

    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems


def tokenize_only(text):

    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
   
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens

# %%
Heading_stemmed = []
Heading_tokenized = []
for i in Heading:
    allwords_stemmed = tokenize_and_stem(i) #for each item in 'Heading', tokenize/stem
    Heading_stemmed.extend(allwords_stemmed) #extend the 'Heading_stemmed' list
    
    allwords_tokenized = tokenize_only(i)
    Heading_tokenized.extend(allwords_tokenized)

# %%
words_frame = pd.DataFrame({'words': Heading_tokenized}, index = Heading_stemmed)

# %%
words_frame.head(10)
# Out:
#                  words
# boss              boss
# girl              girl
# present     presenting
# rhea              rhea
# kapoor          kapoor
# bollywood    bollywood
# s                    s
# bulwark        bulwark
# against        against
# patriarchi  patriarchy

# %% [markdown]
# ## TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(max_df=0.8, max_features=200000,
                                 stop_words='english',
                                 use_idf=True, tokenizer=tokenize_and_stem, ngram_range=(1,4))

# %%
tfidf_matrix = vectorizer.fit_transform(Heading)

# %%
print(tfidf_matrix.shape)
# Out:
# (64, 1383)

# %%
terms = vectorizer.get_feature_names()

# %% [markdown]
# ### Cosine Similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
dist = cosine_similarity(tfidf_matrix)

# %%
dist.shape
# Out:
# (64, 64)

# %% [markdown]
# ### K-Means

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import numpy as np
import pandas as pd

# %%
n_clusters = list (range (14,20))
min=999
for n in n_clusters:
    km_ss = KMeans(n_clusters=n)
    #km_ss.fit(tfidf_matrix) 
    clusters_ss = km_ss.fit_predict(tfidf_matrix)
    #centers_ss = km_ss.cluster_centers_ 
    score = silhouette_score(dist,clusters_ss)
    if min>score:
        min=score
        n_score=n
    print ("For n = {}, silhouette score is {})".format(n, score))
# Out:
# For n = 14, silhouette score is 0.11306534536952906)
# For n = 15, silhouette score is 0.13806224414629975)
# For n = 16, silhouette score is 0.12714026907552084)
# For n = 17, silhouette score is 0.11364316037411712)
# For n = 18, silhouette score is 0.13007773873917378)
# For n = 19, silhouette score is 0.1380088691048395)

# %%
n_score
# Out:
# 14

# %%
num_clusters = n_score
km = KMeans(n_clusters=num_clusters)
km.fit(tfidf_matrix)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=14, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
clusters = km.labels_.tolist()

# %%
lifestyle['Cluster'] = clusters

# %%
lifestyle['Cluster'].value_counts()
# Out:
# 2     11
# 4      9
# 5      7
# 0      6
# 9      5
# 8      5
# 3      5
# 12     3
# 11     3
# 6      3
# 13     2
# 10     2
# 1      2
# 7      1
# Name: Cluster, dtype: int64

# %% [markdown]
# ### Plotting the points

# %%
import os  # for os.path.basename

import matplotlib.pyplot as plt
import matplotlib as mpl

from sklearn.manifold import MDS

MDS()

mds = MDS(n_components=2, dissimilarity="precomputed", random_state=1)

pos = mds.fit_transform(dist)  # shape (n_components, n_samples)

xs, ys = pos[:, 0], pos[:, 1]
print()
print()

# %%
cluster_names = {}
keys = range(n_score)   ## n_score = number of clusters
for i in keys:
       cluster_names[i] = 'Cluster '+str(i)
print(cluster_names)
# Out:
# {0: 'Cluster 0', 1: 'Cluster 1', 2: 'Cluster 2', 3: 'Cluster 3', 4: 'Cluster 4', 5: 'Cluster 5', 6: 'Cluster 6', 7: 'Cluster 7', 8: 'Cluster 8', 9: 'Cluster 9', 10: 'Cluster 10', 11: 'Cluster 11', 12: 'Cluster 12', 13: 'Cluster 13'}

# %%
number_of_colors = n_score

color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
             for i in range(number_of_colors)]
cluster_colors={}
for i in range(len(color)):
    cluster_colors[i]=color[i]
print(cluster_colors)
# Out:
# {0: '#7D66D1', 1: '#CE57E1', 2: '#51E785', 3: '#C21BBE', 4: '#196A38', 5: '#40F4A2', 6: '#91485D', 7: '#160BD3', 8: '#887D82', 9: '#DC7343', 10: '#22903D', 11: '#00E0A0', 12: '#4C294B', 13: '#2AE846'}

# %%
# %matplotlib inline 
df_plot= pd.DataFrame(dict(x=xs, y=ys, label=clusters, title=Heading)) 
df_plot.head()
# Out:
#           x         y  label  \
# 0 -0.000006 -0.002098      0
# 1 -0.000528  0.000046      2
# 2  0.000000  0.000000      7
# 3 -0.000783 -0.001151     13
# 4 -0.000022 -0.000548      2
#
#                                                title
# 0  Boss Girl: Presenting Rhea Kapoor! Bollywood’s...
# 1  Humour: Restaurants and their endless need for...
# 2                    Travel: The Serbian melting pot
# 3  The rise of the fall: Why mobile phone buyers ...
# 4  Lady Gaga exhibits her quirky costume collecti...

# %%
groups = df_plot.groupby('label')

# %%
fig, ax = plt.subplots(figsize=(15, 8))

for name,group in groups:
    ax.plot(group.x, group.y, marker='o',linestyle='',ms=12, label=cluster_names[name],color=cluster_colors[name],mec='none')
    ax.set_aspect('auto')   
    ax.tick_params(axis='x',which='both',bottom='off',top='off',labelbottom='off')
    ax.tick_params(axis= 'y',which='both',left='off',top='off',labelleft='off')
ax.legend(numpoints=1)

for i in range(len(df_plot)):
    ax.text(df_plot.iloc[i]['x'], df_plot.iloc[i]['y'], df_plot.iloc[i]['title'], size=7)

# %% [markdown]
# ## Cluster Similarity

# %%
df_sorted=lifestyle.sort_values(by='Cluster').reset_index()
df_sorted.drop(['index'],axis=1,inplace=True)

# %%
df_sorted
# Out:
#            Newspaper                                            Heading  \
#
# [64 rows x 6 columns]

# %%
grp = lifestyle.sort_values('Cluster').groupby(['Cluster'],as_index=False)

# %%
cluster_similarity_value =[]
def cluster_similarity(cluster):
    try:
        x=[]

        cluster_heading=cluster['Heading']
        #print(cluster['Heading'])
        cluster_matrix = vectorizer.fit_transform(cluster_heading)
        cluster_dist = cosine_similarity(cluster_matrix)
        cluster_elements_count = pd.DataFrame.count(cluster)
        #print(cluster_elements_count[0])


        for i in cluster_dist:
            #z=(i.sum()-1)/cluster_elements_count
            if((cluster_elements_count[0]-1)==0):
                y=1
            else:
                y=float("{0:.2f}".format(((i.sum())/(cluster_elements_count[0]))))
            x.append(y)
            cluster_similarity_value.append(y)

        
        print(x)

        print()
        print()
    except:
        for i in range(len(cluster['Heading'])):
            x.append(1)
            cluster_similarity_value.append(1)
        print(x)
        print()
        print()

# %%
for i in range(n_score):
    cluster_similarity(grp.get_group(i))
# Out:
# [0.18, 0.17, 0.17, 0.17, 0.17, 0.18]
#
#
# [1, 1]
#
#
# [0.1, 0.19, 0.09, 0.19, 0.09, 0.09, 0.09, 0.1, 0.09, 0.09, 0.09]
#
#
# [0.25, 0.41, 0.22, 0.41, 0.27]
#
#
# [0.13, 0.12, 0.12, 0.15, 0.12, 0.13, 0.11, 0.12, 0.12]
#
#
# [0.16, 0.15, 0.15, 0.15, 0.18, 0.16, 0.15]
#
#
# [0.67, 0.67, 0.33]
#
#
# [1]
#
#
# [0.21, 0.21, 0.21, 0.21, 0.2]
#
#
# [0.41, 0.21, 0.21, 0.21, 0.41]
#
#
# [1, 1]
#
#
# [0.34, 0.35, 0.34]
#
#
# [0.33, 0.33, 0.33]
#
#
# [0.5, 0.5]

# %%
df_sorted['cluster_similarity_value']=cluster_similarity_value

# %%
df_sorted.groupby('Cluster')['cluster_similarity_value'].mean()
# Out:
# Cluster
# 0     0.173333
# 1     1.000000
# 2     0.110000
# 3     0.312000
# 4     0.124444
# 5     0.157143
# 6     0.556667
# 7     1.000000
# 8     0.208000
# 9     0.290000
# 10    1.000000
# 11    0.343333
# 12    0.330000
# 13    0.500000
# Name: cluster_similarity_value, dtype: float64

# %%
df_sorted.head()
# Out:
#           Newspaper                                            Heading  \
# 0  Hindiustan Times  Boss Girl: Presenting Rhea Kapoor! Bollywood’s...
# 1    Indian Express  When you are down in the dumps, it’s even more...
# 2    Indian Express  Cranberries may help combat superbugs, says study
# 3  Hindiustan Times  Fifth edition of the Fetes Galantes brings Fra...
# 4  Hindiustan Times   What’s hot in ice cream? A scoop on new flavours
#
#          Date         Time                                                URL  \
# 0  2019-05-25     23:27:00  https://www.hindustantimes.com/brunch/boss-gir...
# 1  2019-05-31   5:30:50 am  https://indianexpress.com/article/lifestyle/li...
# 2  2019-05-31  11:13:32 am  https://indianexpress.com/article/lifestyle/he...
# 3  2019-05-29     10:44:00  https://www.hindustantimes.com/fashion-and-tre...
# 4  2019-05-29     11:02:00  https://www.hindustantimes.com/more-lifestyle/...
#
#    Cluster  cluster_similarity_value
# 0        0                      0.18
# 1        0                      0.17
# 2        0                      0.17
# 3        0                      0.17
# 4        0                      0.17

# %%
grp = df_sorted.sort_values('Cluster').groupby(['Cluster'],as_index=False)

# %%
col=df_sorted.columns

# %%
temp_more =[]
temp_less  =[]

# %%
def fix_you(cluster):
    cluster_mean = cluster['cluster_similarity_value'].mean()
    for i in range(len(cluster)):
        if (cluster.iloc[i]['cluster_similarity_value']<cluster_mean):
            temp_less.append(cluster.iloc[i])
        else:
            temp_more.append(cluster.iloc[i])

# %%
for i in range(n_score):
    fix_you(grp.get_group(i))

# %%
df_more_similar=pd.DataFrame(temp_more,columns=col)
df_less_similar=pd.DataFrame(temp_less,columns=col)

# %%
Result = df_more_similar.sort_values('Cluster').groupby(['Cluster'],as_index=False).apply(lambda x: x.sample(1)) ## picking 1 out of each cluster having mean+std/2 < centroid 
Result.head()
# Out:
#              Newspaper                                            Heading  \
# 0 5   Hindiustan Times  Bollywood celebrity inspired beach accessories...
# 1 7        India Today   New mom Meghan Markle will not meet Donald Tr...
# 2 9     Indian Express  ‘We need diversity behind the camera as well’:...
# 3 20    Indian Express  World No Tobacco Day 2019: Seven ways to avoid...
# 4 27       India Today   Ananya Panday looks like a summer dream in fl...
#
#             Date         Time  \
# 0 5   2019-05-29     13:42:00
# 1 7   2019-05-31        11:37
# 2 9   2019-05-31  12:00:33 am
# 3 20  2019-05-31   8:30:33 am
# 4 27  2019-05-31        11:37
#
#                                                     URL  Cluster  \
# 0 5   https://www.hindustantimes.com/fashion-and-tre...        0
# 1 7   https://timesofindia.indiatimes.com/lifestyle/...        1
# 2 9   https://indianexpress.com/article/lifestyle/ar...        2
# 3 20  https://indianexpress.com/article/lifestyle/he...        3
# 4 27  https://timesofindia.indiatimes.com/lifestyle/...        4
#
#       cluster_similarity_value
# 0 5                       0.18
# 1 7                       1.00
# 2 9                       0.19
# 3 20                      0.41
# 4 27                      0.15

# %%
Result = Result.reset_index().drop(['level_0','level_1'],axis=1)

# %%
Result = Result.append(df_less_similar)

# %%
Result = Result.sort_values(by='Cluster')

# %%
Result
# Out:
#            Newspaper                                            Heading  \
# 0   Hindiustan Times  Bollywood celebrity inspired beach accessories...
# 4   Hindiustan Times   What’s hot in ice cream? A scoop on new flavours
# 3   Hindiustan Times  Fifth edition of the Fetes Galantes brings Fra...
# 2     Indian Express  Cranberries may help combat superbugs, says study
# 1     Indian Express  When you are down in the dumps, it’s even more...
# 1        India Today   New mom Meghan Markle will not meet Donald Tr...
# 8     Indian Express  Dal Raisina: All you need to know about the sp...
# 10       India Today   A weekend in the land of Bond: Bonfires and b...
# 12  Hindiustan Times  Chaat is always a childhood memory — We can’t ...
# 14  Hindiustan Times  Resurgent Capital: In and around Bogota, Columbia
# 15  Hindiustan Times  Humour: Restaurants and their endless need for...
# 16  Hindiustan Times  Stress during pregnancy affects reproductive f...
# 17  Hindiustan Times  Lady Gaga exhibits her quirky costume collecti...
# 18  Hindiustan Times  From street-side drug addicts to trained artists
# 13  Hindiustan Times  Seriously Cyrus: Is the salad worth the forbid...
# 2     Indian Express  ‘We need diversity behind the camera as well’:...
# 13  https://www.hindustantimes.com/brunch/the-rise...       13
#
#     cluster_similarity_value
# 0                       0.18
# 4                       0.17
# 3                       0.17
# 2                       0.17
# 1                       0.17
# 1                       1.00
# 8                       0.10
# 10                      0.09
# 12                      0.09
# 14                      0.09
# 15                      0.10
# 16                      0.09
# 17                      0.09
# 18                      0.09
# 13                      0.09
# 2                       0.19
# 21                      0.22
# 23                      0.27
# 19                      0.25
# 3                       0.41
# 25                      0.12
# 26                      0.12
# 31                      0.12
# 28                      0.12
# 30                      0.11
# 32                      0.12
# 4                       0.15
# 5                       0.18
# 34                      0.15
# 35                      0.15
# 36                      0.15
# 39                      0.15
# 42                      0.33
# 6                       0.67
# 7                       1.00
# 8                       0.21
# 48                      0.20
# 51                      0.21
# 50                      0.21
# 9                       0.41
# 52                      0.21
# 10                      1.00
# 58                      0.34
# 56                      0.34
# 11                      0.35
# 12                      0.33
# 13                      0.50

# %%
outname ='Lifestyle-'+str(Today_date)+'.csv'
x=r"C:\Users\drago\Documents\GitHub\Summer-Project\Lifestyle\Output CSV\ "
date_today= Today_date +'\ '
outdir=x[:-1]
if not os.path.exists(outdir):
    os.mkdir(outdir)
fullname = os.path.join(outdir, outname)

# %%
Result.to_csv(fullname,index=False,encoding='utf-8')

# %%
pd.read_csv(fullname)
# Out:
#            Newspaper                                            Heading  \
# 0   Hindiustan Times  Bollywood celebrity inspired beach accessories...
# 1   Hindiustan Times   What’s hot in ice cream? A scoop on new flavours
# 2   Hindiustan Times  Fifth edition of the Fetes Galantes brings Fra...
# 3     Indian Express  Cranberries may help combat superbugs, says study
# 4     Indian Express  When you are down in the dumps, it’s even more...
# 5        India Today   New mom Meghan Markle will not meet Donald Tr...
# 6     Indian Express  Dal Raisina: All you need to know about the sp...
# 7        India Today   A weekend in the land of Bond: Bonfires and b...
# 8   Hindiustan Times  Chaat is always a childhood memory — We can’t ...
# 9   Hindiustan Times  Resurgent Capital: In and around Bogota, Columbia
# 10  Hindiustan Times  Humour: Restaurants and their endless need for...
# 11  Hindiustan Times  Stress during pregnancy affects reproductive f...
# 12  Hindiustan Times  Lady Gaga exhibits her quirky costume collecti...
# 13  Hindiustan Times  From street-side drug addicts to trained artists
# 14  Hindiustan Times  Seriously Cyrus: Is the salad worth the forbid...
# 15    Indian Express  ‘We need diversity behind the camera as well’:...
# 16    Indian Express  World No Tobacco Day 2019: Why smoking is dang...
# 17    Indian Express  World No Tobacco Day 2019: ‘Smokeless tobacco ...
# 18    Indian Express  World No Tobacco Day 2019: How smokeless tobac...
# 19    Indian Express  World No Tobacco Day 2019: Seven ways to avoid...
# 20       India Today   Janhvi Kapoor teaches how to do gym fashion r...
# 21       India Today    Let Kangana Ranaut in all-white attire teach...
# 22  Hindiustan Times             Summer special: For the love of lychee
# 23    Indian Express                                  Any Dream Will Do
# 24       India Today   Katrina Kaif smiles for the paps in thigh-sli...
# 25       India Today   Shibani Dandekar trolled for copying Deepika ...
# 26       India Today   Ananya Panday looks like a summer dream in fl...
# 27       India Today   Sara Ali Khan goes boho chic in floral print ...
# 28       India Today   Hina Khan on flak for her Cannes 2019 debut: ...
# 29  Hindiustan Times  Identity quest: An art fest that goes beyond t...
# 30       India Today   Chitrangada Singh takes casual fashion to the...
