# %%
import requests
import bs4
import datetime
now = datetime.datetime.now()

# %%
Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
def record_date_time(z):
    req = requests.get(z)
    soup_url= bs4.BeautifulSoup(req.text,'lxml')
    date_time = soup_url.find('time')['datetime']
    date =date_time[:10]
    time= date_time[11:17]+'00'

    return date,time

def record_URL(x):
    y='https://timesofindia.indiatimes.com'
    url = y+x 
    return url

# %%
link ='https://timesofindia.indiatimes.com/life-style'

# %%
res = requests.get(link)

# %%
soup =bs4.BeautifulSoup(res.text,'lxml')

# %%
toi_1=soup.select(".small_video_lft.chng_lfttxt")
#content=toi[0].findAll("span", {"class" : "w_tle"})

# %%
toi_1[1]
# Out:
# <div class="small_video_lft chng_lfttxt"><a alt="Love Horoscope for June: Romance or disappointments?" data-action="SectionListing_NewsItem" data-ga="true" data-label="Featured" data-value="3" href="/life-style/relationships/love-sex/love-horoscope-for-june-will-it-be-a-month-of-romantic-bliss-or-disappointments/photostory/69581342.cms" title="Love Horoscope for June: Romance or disappointments?"><div class="lftbig_img"><img alt="Love Horoscope for June: Romance or disappointments?" data-plugin="imagesection1" src="https://static.toiimg.com/thumb/msid-69581342,imgsize-,width-301,height-222/69581342.jpg" title="Love Horoscope for June: Romance or disappointments?"/></div><div class="lftbig_txt"><h3>Love Horoscope for June: Romance or disappointments?</h3></div><i class="ent_red_sprite wht_storyicon posicon"></i></a></div>

# %%
toi_1[1].text
# Out:
# 'Love Horoscope for June: Romance or disappointments?'

# %%
toi_1[0].find('a')['href']
# Out:
# '/life-style/health-fitness/health-news/try-these-5-yoga-poses-before-bed-to-sleep-better/photostory/69598436.cms'

# %%
records=[]
for record in toi_1:
    Heading = record.text
    URL= record_URL(record.find('a')['href'])
    Date = Today_date
    Time = Today_time
    #Date,Time= record_date_time(URL)
    #Time = record_time(URL)
    Newspaper = 'Time of India'
    records.append((Newspaper,Heading,Date,Time,URL))

# %%
toi_2=soup.select(".section_box")

# %%
for i in toi_2:
    li = i.findAll('li')
    for record in li[:-2]:
        Heading = record.text
        URL= record_URL(record.find('a')['href'])
        Date = Today_date
        Time = Today_time
        #Date,Time= record_date_time(URL)
        #Time = record_time(URL)
        Newspaper = 'Time of India'
        records.append((Newspaper,Heading,Date,Time,URL))

# %%
import pandas as pd
df=pd.DataFrame(records,columns=['Newspaper','Heading','Date','Time','URL'])
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#         Newspaper                                            Heading  \
# 0   Time of India  Try these 5 yoga poses before bed to sleep better
# 1   Time of India  Love Horoscope for June: Romance or disappoint...
# 2   Time of India             What is a watermelon diet? We tell you
# 3   Time of India                       Why is a pedicure necessary?
# 4   Time of India                  People who read more are happier!
# 5   Time of India               Aftermaths of eating instant noodles
# 6   Time of India  Will this be a month of romantic bliss or disa...
# 7   Time of India     My partner enjoys watching porn. It is normal?
# 8   Time of India  Try these 5 yoga poses before bed to sleep better
# 9   Time of India  What exactly are 'blue balls' in a man? Do the...
# 10  Time of India  Sara Ali Khan proves PINK is the HOTTEST hue t...
# 11  Time of India         Kangana is a style chameleon, here's proof
# 12  Time of India                 ICC Cricket World Cup 2019—a guide
# 13  Time of India      Rohtang Pass to open for tourists from June 1
# 14  Time of India  How to get Kareena Kapoor's rope braid in 4 si...
# 15  Time of India                       Why is a pedicure necessary?
# 16  Time of India           Movie adaptations of books authors hated
# 17  Time of India            Micro review: 'Past Tense' by Lee Child
# 18  Time of India  Person's home gives insights into their person...
# 19  Time of India  Want to overcome money blockages and attract f...
# 20  Time of India                                      Achari Mutton
# 21  Time of India                               Baked Coconut Shrimp
# 22  Time of India  "I feel my child is getting neglected because ...
# 23  Time of India  "My daughter thinks boys are stronger than gir...
# 24  Time of India  Kailash Kher: I try to give a platform to moti...
# 25  Time of India  Happy Buddha Purnima 2019: Wishes, messages, p...
# 26  Time of India  There is a need to develop mountaineering cult...
# 27  Time of India          Fruits still chemically ripened in Kerala
# 28  Time of India  What happens to your body after eating instant...
