# %%
import requests
import bs4
import datetime
now = datetime.datetime.now()

# %%
Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
def record_date_time(z):
    req = requests.get(z)
    soup_url= bs4.BeautifulSoup(req.text,'lxml')
    date_time = soup_url.find('time')['datetime']
    date =date_time[:10]
    time= date_time[11:17]+'00'

    return date,time

def record_URL(x):
    y='https://timesofindia.indiatimes.com'
    url = y+x 
    return url

# %%
link ='https://timesofindia.indiatimes.com/life-style'

# %%
res = requests.get(link)

# %%
soup =bs4.BeautifulSoup(res.text,'lxml')

# %%
toi_1=soup.select(".small_video_lft.chng_lfttxt")
#content=toi[0].findAll("span", {"class" : "w_tle"})

# %%
toi_1[1]
# Out:
# <div class="small_video_lft chng_lfttxt"><a alt="Want to read more books? Follow these tips!" data-action="SectionListing_NewsItem" data-ga="true" data-label="Featured" data-value="3" href="/life-style/books/features/want-to-read-more-books-follow-these-tips/photostory/69544534.cms" title="Want to read more books? Follow these tips!"><div class="lftbig_img"><img alt="Want to read more books? Follow these tips!" data-plugin="imagesection1" src="https://static.toiimg.com/thumb/msid-69544534,imgsize-,width-301,height-222/69544534.jpg" title="Want to read more books? Follow these tips!"/></div><div class="lftbig_txt"><h3>Want to read more books? Follow these tips!</h3></div><i class="ent_red_sprite wht_storyicon posicon"></i></a></div>

# %%
toi_1[1].text
# Out:
# 'Want to read more books? Follow these tips!'

# %%
toi_1[0].find('a')['href']
# Out:
# '/life-style/health-fitness/health-news/from-weight-loss-to-anti-ageing-7-unbelievable-benefits-of-sleeping-naked/photostory/69542896.cms'

# %%
records=[]
for record in toi_1:
    Heading = record.text
    URL= record_URL(record.find('a')['href'])
    Date = Today_date
    Time = Today_time
    #Date,Time= record_date_time(URL)
    #Time = record_time(URL)
    Newspaper = 'Time of India'
    records.append((Newspaper,Heading,Date,Time,URL))

# %%
toi_2=soup.select(".section_box")

# %%
for i in toi_2:
    li = i.findAll('li')
    for record in li[:-2]:
        Heading = record.text
        URL= record_URL(record.find('a')['href'])
        Date = Today_date
        Time = Today_time
        #Date,Time= record_date_time(URL)
        #Time = record_time(URL)
        Newspaper = 'Time of India'
        records.append((Newspaper,Heading,Date,Time,URL))

# %%
import pandas as pd
df=pd.DataFrame(records,columns=['Newspaper','Heading','Date','Time','URL'])
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#         Newspaper                                            Heading  \
# 0   Time of India         7 unbelievable benefits of sleeping naked!
# 1   Time of India        Want to read more books? Follow these tips!
# 2   Time of India    This real-life funny bidai scene is going viral
# 3   Time of India           Stop your make-up from melting in summer
# 4   Time of India             Confused if your girlfriend loves you?
# 5   Time of India            Why you shouldn’t eat from a dented can
# 6   Time of India  Women are happier without a husband and kids: ...
# 7   Time of India      Confused if your girlfriend loves you or not?
# 8   Time of India      Never make these 7 comments on SKINNY PEOPLE!
# 9   Time of India  WHO calls ‘Burnout’ a medical condition, then ...
# 10  Time of India  How to dress for work Bollywood style this summer
# 11  Time of India       You can't miss Gabrielle's maternity fashion
# 12  Time of India  Exploring countries that have simpler immigrat...
# 13  Time of India        5 places in the world that are inaccessible
# 14  Time of India  6 top reasons your hair keeps FALLING and how ...
# 15  Time of India  7 ways you can stop your make-up from melting ...
# 16  Time of India        Want to read more books? Follow these tips!
# 17  Time of India          Vivekananda book to get screen adaptation
# 18  Time of India       Vastu tips: Best colours for different rooms
# 19  Time of India         Sona inspires Mona Jaswani to get in shape
# 20  Time of India                            Spanish Potato Omelette
# 21  Time of India  Chicken Salad with Spring Onions and Sun-dried...
# 22  Time of India         How parents can bully-proof their children
# 23  Time of India  "My 4-year-old has a crush on a boy in his cla...
# 24  Time of India  Kailash Kher: I try to give a platform to moti...
# 25  Time of India  Happy Buddha Purnima 2019: Wishes, messages, p...
# 26  Time of India  This real-life funny bidai scene is going to m...
# 27  Time of India  We are sure you would want to own this magical...
