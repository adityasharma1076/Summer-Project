# %%
import requests
import bs4
import pandas as pd
import os

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
link = 'https://www.hindustantimes.com/education/'
res = requests.get(link)

# %%
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
content = soup.select('.media-body')

# %%
content[0]
# Out:
# <div class="media-body">
# <div class="media-heading headingfive">
# <a href="https://www.hindustantimes.com/education/jnuee-2019-take-action-against-entrance-paper-leaks-jnusu-tells-admin/story-eIm5PehwslLxVkxAclwSyN.html">JNUEE 2019: Take action against entrance paper leaks, JNUSU tells admin</a>
# </div>
# <span class="time-dt mb-5">Jun 11, 2019 09:53</span>
# </div>

# %%
content[0].find('a').text
# Out:
# 'JNUEE 2019: Take action against entrance paper leaks, JNUSU tells admin'

# %%
content[0].find('a')['href']
# Out:
# 'https://www.hindustantimes.com/education/jnuee-2019-take-action-against-entrance-paper-leaks-jnusu-tells-admin/story-eIm5PehwslLxVkxAclwSyN.html'

# %%
content[0].find('span').text
# Out:
# 'Jun 11, 2019 09:53'

# %%
x=str.split(content[0].find('span').text)

# %%
x[3]
# Out:
# '09:53'

# %%
records=[]
for record in content:
    Heading = record.find('a').text
    URL = record.find('a')['href']
    Newspaper = 'Hindiustan Times'
    dt=str.split(record.find('span').text)
    Date = dt[0]+' '+dt[1]+' '+dt[2]
    Time = dt[3]+':00'
    records.append((Newspaper,Heading,Date,Time,URL))

# %%
df=pd.DataFrame(records,columns=['Newspaper','Heading','Date','Time','URL'])
#df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#            Newspaper                                            Heading  \
# 0   Hindiustan Times  JNUEE 2019: Take action against entrance paper...
# 1   Hindiustan Times  Admissions go on-campus as glitches hit online...
# 2   Hindiustan Times  UGC cracks whip to fill vacant posts in univer...
# 3   Hindiustan Times  TS ICET Result 2019: Telangana ICET results on...
# 4   Hindiustan Times  Scholarships to 5 crore minority students in n...
# 5   Hindiustan Times  8-year-old Indian expat student collects 15,00...
# 6   Hindiustan Times  HSSC Recruitment 2019: Over 6000 vacancies ann...
# 7   Hindiustan Times  AIIMS MBBS Result 2019 likely to be declared t...
# 8   Hindiustan Times            FYJC race: State push for SSC students?
# 9   Hindiustan Times  NTA ICAR AIEEA admit card to be released on Ju...
# 10  Hindiustan Times  Admissions go on-campus as glitches hit online...
# 11  Hindiustan Times  JNUEE 2019: Take action against entrance paper...
# 12  Hindiustan Times  UGC cracks whip to fill vacant posts in univer...
# 13  Hindiustan Times  Women are boxing all the way in Delhi Universi...
# 14  Hindiustan Times  Delhi HC seeks Centre, DU’s stand on plea chal...
# 15  Hindiustan Times  DU Admissions 2019: Entrance tests to begin fr...
# 16  Hindiustan Times  BHU SET Result 2019 declared, here’s direct li...
# 17  Hindiustan Times  Meet Ajay Bahadur Singh, once a tea seller, no...
# 18  Hindiustan Times  Hit by 'discrepancies' galore, LNMU exam keeps...
# 19  Hindiustan Times  Patiala, Amritsar medical colleges to retain 2...
# 20  Hindiustan Times  Ranchi University to launch new admission syst...
# 21  Hindiustan Times  JKBOSE class 11th annual result 2019 for Jammu...
# 22  Hindiustan Times  DU to add maps for NCWEB centres on online portal
# 23  Hindiustan Times  UPSC Admit card for Engineering Services (main...
# 24  Hindiustan Times  SBI SO Recruitment 2019: Application for 579 v...
