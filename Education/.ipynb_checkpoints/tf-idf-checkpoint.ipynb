# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import random
import os

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
prefix_dir =r"C:\Users\drago\Documents\GitHub\Summer-Project\Education\Combined CSV\ "
suffix_dir = 'combined_csv-'+Today_date
today_csv=prefix_dir[:-1] +suffix_dir

# %%
education = pd.read_csv('combined_csv.csv')

# %%
education.head()
# Out:
#           Newspaper                                            Heading  \
# 0  Hindiustan Times  WBCHSE 12th Result 2019: Where and how to chec...
# 1  Hindiustan Times  NTA UGC- NET admit card 2019  to release tomor...
# 2  Hindiustan Times  UPSC civil services 2019 prelims on June 2: Re...
# 3  Hindiustan Times  GSHSEB Gujarat 12th Board Results: 79 schools ...
# 4  Hindiustan Times  Mumbra’s kids get the reading bug from ‘suitca...
#
#          Date      Time                                                URL
# 0  2019-05-26  15:08:00  https://www.hindustantimes.com/education/wbchs...
# 1  2019-05-26  12:24:00  https://www.hindustantimes.com/education/nta-u...
# 2  2019-05-26  09:12:00  https://www.hindustantimes.com/education/upsc-...
# 3  2019-05-26  15:33:00  https://www.hindustantimes.com/education/gshse...
# 4  2019-05-26  15:29:00  https://www.hindustantimes.com/education/mumbr...

# %%
education.shape
# Out:
# (166, 5)

# %%
df=education[education['Date']=='2019-05-26']
Heading = df['Heading']

# %%
df.head()
# Out:
#           Newspaper                                            Heading  \
# 0  Hindiustan Times  WBCHSE 12th Result 2019: Where and how to chec...
# 1  Hindiustan Times  NTA UGC- NET admit card 2019  to release tomor...
# 2  Hindiustan Times  UPSC civil services 2019 prelims on June 2: Re...
# 3  Hindiustan Times  GSHSEB Gujarat 12th Board Results: 79 schools ...
# 4  Hindiustan Times  Mumbra’s kids get the reading bug from ‘suitca...
#
#          Date      Time                                                URL  \
# 0  2019-05-26  15:08:00  https://www.hindustantimes.com/education/wbchs...
# 1  2019-05-26  12:24:00  https://www.hindustantimes.com/education/nta-u...
# 2  2019-05-26  09:12:00  https://www.hindustantimes.com/education/upsc-...
# 3  2019-05-26  15:33:00  https://www.hindustantimes.com/education/gshse...
# 4  2019-05-26  15:29:00  https://www.hindustantimes.com/education/mumbr...
#
#    Cluster  sqddist
# 0        1    20.61
# 1        4    21.89
# 2        0    21.68
# 3       11    21.17
# 4       10    20.75

# %%
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
#from sklearn.decomposition import TruncatedSVD

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\drago\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopset = set(stopwords.words('english'))

# %%
#### Delete This
#from sklearn.datasets import fetch_20newsgroups
#categories = ['rec.sport.baseball']
#dataset = fetch_20newsgroups(subset='all',shuffle=True, random_state=42, categories=categories)
#corpus=dataset.data

# %% [markdown]
# Tokenizing and Stemming

# %%
import nltk
import re

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\drago\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")

# %%
def tokenize_and_stem(text):
   
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []

    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems


def tokenize_only(text):

    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
   
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens

# %%
Heading_stemmed = []
Heading_tokenized = []
for i in Heading:
    allwords_stemmed = tokenize_and_stem(i) #for each item in 'Heading', tokenize/stem
    Heading_stemmed.extend(allwords_stemmed) #extend the 'Heading_stemmed' list
    
    allwords_tokenized = tokenize_only(i)
    Heading_tokenized.extend(allwords_tokenized)

# %%
 Heading_tokenized[:10]    # 10 out of all
# Out:
# ['wbchse',
#  '12th',
#  'result',
#  'where',
#  'and',
#  'how',
#  'to',
#  'check',
#  'west',
#  'bengal']

# %%
Heading_stemmed[:10]   # 10 out of all
# Out:
# ['wbchse',
#  '12th',
#  'result',
#  'where',
#  'and',
#  'how',
#  'to',
#  'check',
#  'west',
#  'bengal']

# %%
words_frame = pd.DataFrame({'words': Heading_tokenized}, index = Heading_stemmed)

# %%
words_frame.head(10)
# Out:
#          words
# wbchse  wbchse
# 12th      12th
# result  result
# where    where
# and        and
# how        how
# to          to
# check    check
# west      west
# bengal  bengal

# %% [markdown]
# TF-IDF

# %%
##Important : min_df
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(max_df=0.8, max_features=200000,
                                 stop_words='english',
                                 use_idf=True, tokenizer=tokenize_and_stem, ngram_range=(1,4))

# %%
tfidf_matrix = vectorizer.fit_transform(Heading)

# %%
print(tfidf_matrix.shape)
# Out:
# (41, 894)

# %%
print(tfidf_matrix[0])
# Out:
#   (0, 857)	0.15845261572353014
#   (0, 4)	0.25735955625490525
#   (0, 643)	0.18714034350557604
#   (0, 187)	0.11410797489704727
#   (0, 874)	0.15845261572353014
#   (0, 118)	0.15845261572353014
#   (0, 135)	0.12334300934886556
#   (0, 867)	0.18432718764637646
#   (0, 858)	0.18432718764637646
#   (0, 9)	0.13464577804130654
#   (0, 645)	0.18432718764637646
#   (0, 206)	0.18432718764637646
#   (0, 875)	0.15845261572353014
#   (0, 119)	0.16975538441597113
#   (0, 5)	0.16975538441597113
#   (0, 147)	0.15845261572353014
#   (0, 678)	0.18432718764637646
#   (0, 859)	0.18432718764637646
#   (0, 10)	0.18432718764637646
#   (0, 646)	0.18432718764637646
#   (0, 207)	0.18432718764637646
#   (0, 876)	0.16975538441597113
#   (0, 120)	0.18432718764637646
#   (0, 6)	0.16975538441597113
#   (0, 152)	0.18432718764637646
#   (0, 860)	0.18432718764637646
#   (0, 11)	0.18432718764637646
#   (0, 647)	0.18432718764637646
#   (0, 208)	0.18432718764637646
#   (0, 877)	0.18432718764637646
#   (0, 121)	0.18432718764637646
#   (0, 8)	0.18432718764637646

# %%
vectorizer.get_feature_names()[:]
# Out:
# ['10th',
#  '10th 12th',
#  '10th 12th result',
#  '10th 12th result date',
#  '12th',
#  '12th board',
#  '12th board result',
#  '12th board result school',
#  '12th board result wbchse.nic.in',
#  '12th result',
#  '12th result check',
#  '12th result check west',
#  '12th result date',
#  '12th result date time',
#  '12th result jump',
#  '12th result jump student',
#  '12th result mani',
#  '12th result mani mark',
#  '12th result wbchse',
#  '12th result wbchse uccha',
#  '3rd',
#  '3rd year',
#  '3rd year result',
#  '3rd year result declar',
#  '6th',
#  '6th result',
#  '6th result declar',
#  '6th result declar s',
#  'acut',
#  'acut shortag',
#  'acut shortag teacher',
#  'acut shortag teacher princip',
#  'admiss',
#  'admiss appear',
#  'admiss appear entranc',
#  'admiss appear entranc test',
#  'admiss applic',
#  'admiss applic form',
#  'admiss applic form tomorrow',
#  'admit',
#  'admit card',
#  'admit card june',
#  'admit card releas',
#  'admit card releas s',
#  'admit card releas tomorrow',
#  'advanc',
#  'advanc conduct',
#  'advanc conduct iit',
#  'advanc conduct iit roorke',
#  'advanc exam',
#  'advanc exam tomorrow',
#  'advanc exam tomorrow check',
#  'advanc follow',
#  'advanc follow minut',
#  'advanc follow minut tip',
#  'advic',
#  'advic book',
#  'advic book revis',
#  'aid',
#  'aid sanskrit',
#  'aid sanskrit colleg',
#  'aid sanskrit colleg face',
#  'aiim',
#  'aiim ug',
#  'aiim ug exam',
#  'aiim ug exam conclud',
#  'amin',
#  'amin kanoongo',
#  'amin kanoongo clerk',
#  'amin kanoongo clerk post',
#  'amu',
#  'amu admiss',
#  'amu admiss appear',
#  'amu admiss appear entranc',
#  'analysi',
#  'analysi cut-off',
#  'analysi paper',
#  'analysi paper easier',
#  'analysi paper easier year',
#  'announc',
#  'announc check',
#  'announc check cut-off',
#  'announc check cut-off pst',
#  'appear',
#  'appear entranc',
#  'appear entranc test',
#  'appear entranc test btech',
#  'appear test',
#  'appli',
#  'appli befor',
#  'appli befor june',
#  'applic',
#  'applic form',
#  'applic form tomorrow',
#  'applic form tomorrow check',
#  'armi',
#  'armi women',
#  'armi women recruit',
#  'armi women recruit check',
#  'asi',
#  'asi cisf',
#  'asi cisf result',
#  'asi cisf result announc',
#  'b.com',
#  'b.com 3rd',
#  'b.com 3rd year',
#  'b.com 3rd year result',
#  'b.com year',
#  'b.com year result',
#  'b.com year result declar',
#  'ban',
#  'ban item',
#  'ban item need',
#  'ban item need know',
#  'barch',
#  'barch mba',
#  'befor',
#  'befor june',
#  'bengal',
#  'bengal 12th',
#  'bengal 12th board',
#  'bengal 12th board result',
#  'bengal 12th result',
#  'bengal 12th result wbchse',
#  'bengal board',
#  'bengal board 12th',
#  'bengal board 12th result',
#  'best',
#  'best formula',
#  'best formula document',
#  'best formula document need',
#  'bihar',
#  'bihar lrc',
#  'bihar lrc releas',
#  'bihar lrc releas merit',
#  'board',
#  'board 12th',
#  'board 12th result',
#  'board 12th result date',
#  'board exam',
#  'board exam class',
#  'board gseb',
#  'board gseb 12th',
#  'board gseb 12th result',
#  'board hsc',
#  'board hsc 12th',
#  'board hsc 12th result',
#  'board result',
#  'board result quit',
#  'board result quit class',
#  'board result school',
#  'board result school score',
#  'board result wbchse.nic.in',
#  'board ubs',
#  'board ubs class',
#  'board ubs class 10th',
#  'book',
#  'book revis',
#  'boy',
#  'boy finalist',
#  'boy finalist googl',
#  'boy finalist googl scienc',
#  'btech',
#  'btech barch',
#  'btech barch mba',
#  'bug',
#  'bug suitcas',
#  'bug suitcas librari',
#  'capf',
#  'capf asi',
#  'capf asi cisf',
#  'capf asi cisf result',
#  'card',
#  'card june',
#  'card releas',
#  'card releas s',
#  'card releas s direct',
#  'card releas tomorrow',
#  'card releas tomorrow s',
#  'carri',
#  'carri exam',
#  'carri exam hall',
#  'carri exam hall ban',
#  'cgl',
#  'cgl tier',
#  'cgl tier admit',
#  'cgl tier admit card',
#  'check',
#  'check best',
#  'check best formula',
#  'check best formula document',
#  'check cut-off',
#  'check cut-off pst',
#  'check cut-off pst pet',
#  'check document',
#  'check document need',
#  'check download',
#  'check download link',
#  'check import',
#  'check import instruct',
#  'check section-wis',
#  'check section-wis paper',
#  'check section-wis paper analysi',
#  'check vacanc',
#  'check vacanc elig',
#  'check vacanc elig appli',
#  'check west',
#  'check west bengal',
#  'check west bengal 12th',
#  'cisf',
#  'cisf result',
#  'cisf result announc',
#  'civil',
#  'civil servic',
#  'civil servic prelim',
#  'civil servic prelim june',
#  'class',
#  'class 10th',
#  'class 10th 12th',
#  'class 10th 12th result',
#  'class 6th',
#  'class 6th result',
#  'class 6th result declar',
#  'class entranc',
#  'class entranc exam',
#  'class entranc exam result',
#  'class poverti',
#  'class poverti year',
#  'class poverti year later',
#  'class xii',
#  'clat',
#  'clat appear',
#  'clat appear test',
#  'clat check',
#  'clat check section-wis',
#  'clat check section-wis paper',
#  'clat exam',
#  'clat exam analysi',
#  'clat exam analysi paper',
#  'clerk',
#  'clerk post',
#  'clerk post download',
#  'colleg',
#  'colleg face',
#  'colleg face acut',
#  'colleg face acut shortag',
#  'conclud',
#  'conclud know',
#  'conclud know mani',
#  'conclud know mani mark',
#  'conduct',
#  'conduct iit',
#  'conduct iit roorke',
#  'conduct iit roorke tomorrow',
#  'confirm',
#  'cours',
#  'cours check',
#  'cours check download',
#  'cpo',
#  'cpo result',
#  'cpo result paper',
#  'cpo result paper announc',
#  'cut-off',
#  'cut-off pst',
#  'cut-off pst pet',
#  'cut-off pst pet exam',
#  'date',
#  'date time',
#  'date time confirm',
#  'dbrau',
#  'dbrau result',
#  'dbrau result declar',
#  'dbrau result declar ma',
#  'declar',
#  'declar check',
#  'declar check document',
#  'declar check document need',
#  'declar ma',
#  'declar ma cours',
#  'declar ma cours check',
#  'declar mu.ac.in',
#  'declar s',
#  'declar s direct',
#  'declar s direct link',
#  'delhi',
#  'delhi polic',
#  'delhi polic capf',
#  'delhi polic capf asi',
#  'direct',
#  'direct link',
#  'direct link download',
#  'document',
#  'document need',
#  'document need appli',
#  'download',
#  'download link',
#  'du',
#  'du admiss',
#  'du admiss applic',
#  'du admiss applic form',
#  'dubai-bas',
#  'dubai-bas indian',
#  'dubai-bas indian boy',
#  'dubai-bas indian boy finalist',
#  'easier',
#  'easier year',
#  'elig',
#  'elig appli',
#  'elig appli befor',
#  'elig appli befor june',
#  'entranc',
#  'entranc exam',
#  'entranc exam result',
#  'entranc exam result declar',
#  'entranc test',
#  'entranc test btech',
#  'entranc test btech barch',
#  'everyth',
#  'everyth need',
#  'everyth need know',
#  'everyth need know test',
#  'exam',
#  'exam analysi',
#  'exam analysi paper',
#  'exam analysi paper easier',
#  'exam class',
#  'exam conclud',
#  'exam conclud know',
#  'exam conclud know mani',
#  'exam hall',
#  'exam hall ban',
#  'exam hall ban item',
#  'exam result',
#  'exam result declar',
#  'exam result declar check',
#  'exam schedul',
#  'exam schedul instructor',
#  'exam schedul instructor post',
#  'exam tomorrow',
#  'exam tomorrow check',
#  'exam tomorrow check import',
#  'excel',
#  'excel exam',
#  'expert',
#  'expert advic',
#  'expert advic book',
#  'expert advic book revis',
#  'expert excel',
#  'expert excel exam',
#  'face',
#  'face acut',
#  'face acut shortag',
#  'face acut shortag teacher',
#  'fair',
#  'finalist',
#  'finalist googl',
#  'finalist googl scienc',
#  'finalist googl scienc fair',
#  'follow',
#  'follow minut',
#  'follow minut tip',
#  'follow minut tip expert',
#  'form',
#  'form tomorrow',
#  'form tomorrow check',
#  'form tomorrow check best',
#  'formula',
#  'formula document',
#  'formula document need',
#  'formula document need appli',
#  'googl',
#  'googl scienc',
#  'googl scienc fair',
#  'government-',
#  'government- aid',
#  'government- aid sanskrit',
#  'government- aid sanskrit colleg',
#  'gseb',
#  'gseb 12th',
#  'gseb 12th result',
#  'gseb 12th result jump',
#  'gshseb',
#  'gshseb gujarat',
#  'gshseb gujarat 12th',
#  'gshseb gujarat 12th board',
#  'gujarat',
#  'gujarat 12th',
#  'gujarat 12th board',
#  'gujarat 12th board result',
#  'gujarat board',
#  'gujarat board gseb',
#  'gujarat board gseb 12th',
#  'gujarat board result',
#  'gujarat board result quit',
#  'hall',
#  'hall ban',
#  'hall ban item',
#  'hall ban item need',
#  'hall ticket',
#  'hall ticket releas',
#  'hall ticket releas trb.tn.nic.in',
#  'hsc',
#  'hsc 12th',
#  'hsc 12th result',
#  'hsc 12th result mani',
#  'hssc',
#  'hssc releas',
#  'hssc releas exam',
#  'hssc releas exam schedul',
#  'iit',
#  'iit roorke',
#  'iit roorke tomorrow',
#  'iit roorke tomorrow everyth',
#  'import',
#  'import instruct',
#  'import instruct mark',
#  'import instruct mark scheme',
#  'indian',
#  'indian armi',
#  'indian armi women',
#  'indian armi women recruit',
#  'indian boy',
#  'indian boy finalist',
#  'indian boy finalist googl',
#  'instruct',
#  'instruct mark',
#  'instruct mark scheme',
#  'instruct mark scheme s',
#  'instructor',
#  'instructor post',
#  'instructor post admit',
#  'instructor post admit card',
#  'intermedi',
#  'intermedi re-evalu',
#  'intermedi re-evalu result',
#  'intermedi re-evalu result date',
#  'item',
#  'item need',
#  'item need know',
#  'jee',
#  'jee advanc',
#  'jee advanc conduct',
#  'jee advanc conduct iit',
#  'jee advanc exam',
#  'jee advanc exam tomorrow',
#  'jee advanc follow',
#  'jee advanc follow minut',
#  'jnv',
#  'jnv class',
#  'jnv class entranc',
#  'jnv class entranc exam',
#  'jnvst',
#  'jnvst class',
#  'jnvst class 6th',
#  'jnvst class 6th result',
#  'jump',
#  'jump student',
#  'jump student pass',
#  'jump student pass school',
#  'june',
#  'june read',
#  'june read minut',
#  'june read minut tip',
#  'kanoongo',
#  'kanoongo clerk',
#  'kanoongo clerk post',
#  'kanoongo clerk post download',
#  'kid',
#  'kid read',
#  'kid read bug',
#  'kid read bug suitcas',
#  'know',
#  'know mani',
#  'know mani mark',
#  'know mani mark need',
#  'know test',
#  'later',
#  'later pass',
#  'later pass class',
#  'later pass class xii',
#  'librari',
#  'link',
#  'link download',
#  'list',
#  'list amin',
#  'list amin kanoongo',
#  'list amin kanoongo clerk',
#  'lrc',
#  'lrc releas',
#  'lrc releas merit',
#  'lrc releas merit list',
#  'ma',
#  'ma cours',
#  'ma cours check',
#  'ma cours check download',
#  'madhyamik',
#  'madhyamik result',
#  'madhyamik result tomorrow',
#  'maharashtra',
#  'maharashtra board',
#  'maharashtra board hsc',
#  'maharashtra board hsc 12th',
#  'mani',
#  'mani mark',
#  'mani mark need',
#  'mani mark need pass',
#  'mani mark need qualifi',
#  'mark',
#  'mark need',
#  'mark need pass',
#  'mark need qualifi',
#  'mark need qualifi paper',
#  'mark scheme',
#  'mark scheme s',
#  'mark scheme s need',
#  'mba',
#  'merit',
#  'merit list',
#  'merit list amin',
#  'merit list amin kanoongo',
#  'minut',
#  'minut tip',
#  'minut tip expert',
#  'minut tip expert advic',
#  'minut tip expert excel',
#  'msbshse',
#  'msbshse maharashtra',
#  'msbshse maharashtra board',
#  'msbshse maharashtra board hsc',
#  'mu.ac.in',
#  'mumbai',
#  'mumbai univers',
#  'mumbai univers b.com',
#  'mumbai univers b.com 3rd',
#  'mumbai univers b.com year',
#  'mumbra',
#  'mumbra s',
#  'mumbra s kid',
#  'mumbra s kid read',
#  'navodaya',
#  'navodaya vidyalaya',
#  'navodaya vidyalaya jnv',
#  'navodaya vidyalaya jnv class',
#  'navodaya vidyalaya nvs',
#  'navodaya vidyalaya nvs jnvst',
#  'need',
#  'need appli',
#  'need know',
#  'need know test',
#  'need pass',
#  'need qualifi',
#  'need qualifi paper',
#  'net',
#  'net admit',
#  'net admit card',
#  'net admit card releas',
#  'nta',
#  'nta ugc-',
#  'nta ugc- net',
#  'nta ugc- net admit',
#  'nvs',
#  'nvs jnvst',
#  'nvs jnvst class',
#  'nvs jnvst class 6th',
#  'paper',
#  'paper analysi',
#  'paper analysi cut-off',
#  'paper announc',
#  'paper announc check',
#  'paper announc check cut-off',
#  'paper easier',
#  'paper easier year',
#  'pass',
#  'pass class',
#  'pass class xii',
#  'pass school',
#  'pass school secur',
#  'pass school secur success',
#  'pet',
#  'pet exam',
#  'polic',
#  'polic capf',
#  'polic capf asi',
#  'polic capf asi cisf',
#  'post',
#  'post admit',
#  'post admit card',
#  'post admit card june',
#  'post download',
#  'poverti',
#  'poverti year',
#  'poverti year later',
#  'poverti year later pass',
#  'prelim',
#  'prelim june',
#  'prelim june read',
#  'prelim june read minut',
#  'princip',
#  'pst',
#  'pst pet',
#  'pst pet exam',
#  'punjab',
#  'punjab board',
#  'punjab board exam',
#  'punjab board exam class',
#  'qualifi',
#  'qualifi paper',
#  'quit',
#  'quit class',
#  'quit class poverti',
#  'quit class poverti year',
#  'rate',
#  're-evalu',
#  're-evalu result',
#  're-evalu result date',
#  're-evalu result date time',
#  'read',
#  'read bug',
#  'read bug suitcas',
#  'read bug suitcas librari',
#  'read minut',
#  'read minut tip',
#  'read minut tip expert',
#  'recruit',
#  'recruit check',
#  'recruit check vacanc',
#  'recruit check vacanc elig',
#  'releas',
#  'releas exam',
#  'releas exam schedul',
#  'releas exam schedul instructor',
#  'releas merit',
#  'releas merit list',
#  'releas merit list amin',
#  'releas s',
#  'releas s direct',
#  'releas s direct link',
#  'releas tomorrow',
#  'releas tomorrow s',
#  'releas tomorrow s download',
#  'releas trb.tn.nic.in',
#  'releas trb.tn.nic.in check',
#  'releas trb.tn.nic.in check download',
#  'result',
#  'result announc',
#  'result check',
#  'result check west',
#  'result check west bengal',
#  'result date',
#  'result date time',
#  'result date time confirm',
#  'result declar',
#  'result declar check',
#  'result declar check document',
#  'result declar ma',
#  'result declar ma cours',
#  'result declar mu.ac.in',
#  'result declar s',
#  'result declar s direct',
#  'result jump',
#  'result jump student',
#  'result jump student pass',
#  'result mani',
#  'result mani mark',
#  'result mani mark need',
#  'result paper',
#  'result paper announc',
#  'result paper announc check',
#  'result quit',
#  'result quit class',
#  'result quit class poverti',
#  'result school',
#  'result school score',
#  'result school score result',
#  'result tomorrow',
#  'result wbchse',
#  'result wbchse uccha',
#  'result wbchse uccha madhyamik',
#  'result wbchse.nic.in',
#  'revis',
#  'roorke',
#  'roorke tomorrow',
#  'roorke tomorrow everyth',
#  'roorke tomorrow everyth need',
#  's',
#  's direct',
#  's direct link',
#  's direct link download',
#  's download',
#  's kid',
#  's kid read',
#  's kid read bug',
#  's need',
#  's need know',
#  'sanskrit',
#  'sanskrit colleg',
#  'sanskrit colleg face',
#  'sanskrit colleg face acut',
#  'schedul',
#  'schedul instructor',
#  'schedul instructor post',
#  'schedul instructor post admit',
#  'scheme',
#  'scheme s',
#  'scheme s need',
#  'scheme s need know',
#  'school',
#  'school score',
#  'school score result',
#  'school secur',
#  'school secur success',
#  'school secur success rate',
#  'scienc',
#  'scienc fair',
#  'score',
#  'score result',
#  'section-wis',
#  'section-wis paper',
#  'section-wis paper analysi',
#  'section-wis paper analysi cut-off',
#  'secur',
#  'secur success',
#  'secur success rate',
#  'servic',
#  'servic prelim',
#  'servic prelim june',
#  'servic prelim june read',
#  'shortag',
#  'shortag teacher',
#  'shortag teacher princip',
#  'si',
#  'si delhi',
#  'si delhi polic',
#  'si delhi polic capf',
#  'ssc',
#  'ssc cgl',
#  'ssc cgl tier',
#  'ssc cgl tier admit',
#  'ssc cpo',
#  'ssc cpo result',
#  'ssc cpo result paper',
#  'ssc si',
#  'ssc si delhi',
#  'ssc si delhi polic',
#  'student',
#  'student pass',
#  'student pass school',
#  'student pass school secur',
#  'success',
#  'success rate',
#  'suitcas',
#  'suitcas librari',
#  'teacher',
#  'teacher princip',
#  'telangana',
#  'telangana ts',
#  'telangana ts intermedi',
#  'telangana ts intermedi re-evalu',
#  'test',
#  'test btech',
#  'test btech barch',
#  'test btech barch mba',
#  'tet',
#  'tet hall',
#  'tet hall ticket',
#  'tet hall ticket releas',
#  'thing',
#  'thing carri',
#  'thing carri exam',
#  'thing carri exam hall',
#  'ticket',
#  'ticket releas',
#  'ticket releas trb.tn.nic.in',
#  'ticket releas trb.tn.nic.in check',
#  'tier',
#  'tier admit',
#  'tier admit card',
#  'tier admit card releas',
#  'time',
#  'time confirm',
#  'tip',
#  'tip expert',
#  'tip expert advic',
#  'tip expert advic book',
#  'tip expert excel',
#  'tip expert excel exam',
#  'tn',
#  'tn tet',
#  'tn tet hall',
#  'tn tet hall ticket',
#  'today',
#  'today import',
#  'today import instruct',
#  'today import instruct mark',
#  'today thing',
#  'today thing carri',
#  'today thing carri exam',
#  'tomorrow',
#  'tomorrow check',
#  'tomorrow check best',
#  'tomorrow check best formula',
#  'tomorrow check import',
#  'tomorrow check import instruct',
#  'tomorrow everyth',
#  'tomorrow everyth need',
#  'tomorrow everyth need know',
#  'tomorrow s',
#  'tomorrow s download',
#  'trb.tn.nic.in',
#  'trb.tn.nic.in check',
#  'trb.tn.nic.in check download',
#  'trb.tn.nic.in check download link',
#  'ts',
#  'ts intermedi',
#  'ts intermedi re-evalu',
#  'ts intermedi re-evalu result',
#  'ubs',
#  'ubs class',
#  'ubs class 10th',
#  'ubs class 10th 12th',
#  'uccha',
#  'uccha madhyamik',
#  'uccha madhyamik result',
#  'uccha madhyamik result tomorrow',
#  'ug',
#  'ug exam',
#  'ug exam conclud',
#  'ug exam conclud know',
#  'ugc-',
#  'ugc- net',
#  'ugc- net admit',
#  'ugc- net admit card',
#  'univers',
#  'univers b.com',
#  'univers b.com 3rd',
#  'univers b.com 3rd year',
#  'univers b.com year',
#  'univers b.com year result',
#  'upsc',
#  'upsc civil',
#  'upsc civil servic',
#  'upsc civil servic prelim',
#  'uttarakhand',
#  'uttarakhand board',
#  'uttarakhand board ubs',
#  'uttarakhand board ubs class',
#  'vacanc',
#  'vacanc elig',
#  'vacanc elig appli',
#  'vacanc elig appli befor',
#  'vidyalaya',
#  'vidyalaya jnv',
#  'vidyalaya jnv class',
#  'vidyalaya jnv class entranc',
#  'vidyalaya nvs',
#  'vidyalaya nvs jnvst',
#  'vidyalaya nvs jnvst class',
#  'wbchse',
#  'wbchse 12th',
#  'wbchse 12th result',
#  'wbchse 12th result check',
#  'wbchse uccha',
#  'wbchse uccha madhyamik',
#  'wbchse uccha madhyamik result',
#  'wbchse west',
#  'wbchse west bengal',
#  'wbchse west bengal board',
#  'wbchse.nic.in',
#  'wbjee',
#  'wbjee today',
#  'wbjee today import',
#  'wbjee today import instruct',
#  'wbjee today thing',
#  'wbjee today thing carri',
#  'west',
#  'west bengal',
#  'west bengal 12th',
#  'west bengal 12th board',
#  'west bengal 12th result',
#  'west bengal board',
#  'west bengal board 12th',
#  'women',
#  'women recruit',
#  'women recruit check',
#  'women recruit check vacanc',
#  'xii',
#  'year',
#  'year later',
#  'year later pass',
#  'year later pass class',
#  'year result',
#  'year result declar',
#  'year result declar check',
#  'year result declar mu.ac.in']

# %%
terms = vectorizer.get_feature_names()

# %% [markdown]
# Cosine similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
dist = cosine_similarity(tfidf_matrix)

# %%
dist.shape
# Out:
# (41, 41)

# %%
print(dist)
# Out:
# [[1.         0.         0.         ... 0.01479786 0.02686008 0.        ]
#  [0.         1.         0.         ... 0.02361093 0.         0.        ]
#  [0.         0.         1.         ... 0.         0.         0.        ]
#  ...
#  [0.01479786 0.02361093 0.         ... 1.         0.02822942 0.01517884]
#  [0.02686008 0.         0.         ... 0.02822942 1.         0.03114094]
#  [0.         0.         0.         ... 0.01517884 0.03114094 1.        ]]

# %% [markdown]
# ## K-Means

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import numpy as np
import pandas as pd

# %% [markdown]
# ### Finding Number of Clusters

# %%
n_clusters = list (range (14,20))
min=999
for n in n_clusters:
    km_ss = KMeans(n_clusters=n)
    #km_ss.fit(tfidf_matrix) 
    clusters_ss = km_ss.fit_predict(tfidf_matrix)
    #centers_ss = km_ss.cluster_centers_ 
    score = silhouette_score(dist,clusters_ss)
    if min>score:
        min=score
        n_score=n
    print ("For n = {}, silhouette score is {})".format(n, score))
# Out:
# For n = 14, silhouette score is 0.10318280549805962)
# For n = 15, silhouette score is 0.09014905274703511)
# For n = 16, silhouette score is 0.12911914798195068)
# For n = 17, silhouette score is 0.1416299076060736)
# For n = 18, silhouette score is 0.1265111496503475)
# For n = 19, silhouette score is 0.13892712422314923)

# %%
n_score
# Out:
# 15

# %%
num_clusters = n_score
km = KMeans(n_clusters=num_clusters)
km.fit(tfidf_matrix)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=15, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
clusters = km.labels_.tolist()

# %%
from sklearn.externals import joblib
joblib.dump(km,  'doc_cluster.pkl')
# Out:
# ['doc_cluster.pkl']

# %%
km = joblib.load('doc_cluster.pkl')
clusters = km.labels_.tolist()

# %%
df['Cluster'] = clusters

# %%
#X_dist = km.transform(tfidf_matrix)**2  ###tranform returns distance from centroid
#sqddist = X_dist.sum(axis=1).round(2)
#df['sqddist'] = sqddist

# %%
df['Cluster'].value_counts()
# Out:
# 4     6
# 9     4
# 0     4
# 13    3
# 6     3
# 3     3
# 1     3
# 14    2
# 12    2
# 11    2
# 8     2
# 7     2
# 5     2
# 2     2
# 10    1
# Name: Cluster, dtype: int64

# %% [markdown]
# ## Plotting the points

# %%
import os  # for os.path.basename

import matplotlib.pyplot as plt
import matplotlib as mpl

from sklearn.manifold import MDS

MDS()

mds = MDS(n_components=2, dissimilarity="precomputed", random_state=1)

pos = mds.fit_transform(dist)  # shape (n_components, n_samples)

xs, ys = pos[:, 0], pos[:, 1]
print()
print()

# %%
cluster_names = {}
keys = range(n_score)   ## n_score = number of clusters
for i in keys:
       cluster_names[i] = 'Cluster '+str(i)
print(cluster_names)
# Out:
# {0: 'Cluster 0', 1: 'Cluster 1', 2: 'Cluster 2', 3: 'Cluster 3', 4: 'Cluster 4', 5: 'Cluster 5', 6: 'Cluster 6', 7: 'Cluster 7', 8: 'Cluster 8', 9: 'Cluster 9', 10: 'Cluster 10', 11: 'Cluster 11', 12: 'Cluster 12', 13: 'Cluster 13', 14: 'Cluster 14'}

# %%
number_of_colors = n_score

color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
             for i in range(number_of_colors)]
cluster_colors={}
for i in range(len(color)):
    cluster_colors[i]=color[i]
print(cluster_colors)
# Out:
# {0: '#445C5E', 1: '#A4E790', 2: '#3946DA', 3: '#A8B57C', 4: '#5D5751', 5: '#8FF32C', 6: '#91EE60', 7: '#44663F', 8: '#2A4A2C', 9: '#EE0766', 10: '#AE1E86', 11: '#0066C2', 12: '#D2DB41', 13: '#37D182', 14: '#B98A97'}

# %%
type(cluster_colors)
# Out:
# dict

# %%
# %matplotlib inline 
df_plot= pd.DataFrame(dict(x=xs, y=ys, label=clusters, title=Heading)) 
df_plot.head()
# Out:
#           x         y  label  \
# 0 -0.049381 -0.013907      1
# 1 -0.024432 -0.026985      4
# 2  0.020308  0.021472      0
# 3 -0.003529  0.009295     11
# 4 -0.000007 -0.000395     10
#
#                                                title
# 0  WBCHSE 12th Result 2019: Where and how to chec...
# 1  NTA UGC- NET admit card 2019  to release tomor...
# 2  UPSC civil services 2019 prelims on June 2: Re...
# 3  GSHSEB Gujarat 12th Board Results: 79 schools ...
# 4  Mumbra’s kids get the reading bug from ‘suitca...

# %%
groups = df_plot.groupby('label')

# %%
fig, ax = plt.subplots(figsize=(15, 8))

for name,group in groups:
    ax.plot(group.x, group.y, marker='o',linestyle='',ms=12, label=cluster_names[name],color=cluster_colors[name],mec='none')
    ax.set_aspect('auto')   
    ax.tick_params(axis='x',which='both',bottom='off',top='off',labelbottom='off')
    ax.tick_params(axis= 'y',which='both',left='off',top='off',labelleft='off')
ax.legend(numpoints=1)

for i in range(len(df_plot)):
    ax.text(df_plot.iloc[i]['x'], df_plot.iloc[i]['y'], df_plot.iloc[i]['title'], size=7)

# %% [markdown]
# ### Closest Point to Centroid

# %%
#centers = np.array(km.cluster_centers_)

# %%
#data_99 = [ j for j, cluster in enumerate(clusters) if cluster == 1 ]

# %%
#cluster_tf_matrix = np.zeros( (  len(data_99) , centers.shape[1] ) )
#cluster_tf_matrix

# %%
#for row_num, data in enumerate(data_99):
 #       row = tfidf_matrix[data]
  #      cluster_tf_matrix[row_num] = row

# %%
#clostest_data = []
#for i in range(num_clusters):
 #   center = centers[i]
  #  data_i = [ j for j, cluster in enumerate(clusters) if cluster == i ]
    
    
   # cluster_tf_matrix = np.zeros( (  len(data_i) , centers.shape[1] ) )
    #for row_num, data in enumerate(data_i):
     #   row = tfidf_matrix[data]
      #  cluster_tf_matrix[row_num] = row

# %% [markdown]
# ## Final Result

# %%
#df.sort_values(by='Cluster')

# %%
#print( "Sqd Dist Mean is {} and Std Deviation is {}".format(df['sqddist'].mean(),df['sqddist'].std()))
# Out:
# Sqd Dist Mean is 21.618048780487808 and Std Deviation is 0.4278680842981578

# %%
#dist_mean=df['sqddist'].mean()
#dist_std=df['sqddist'].std()

# %%
#df_less = df[df['sqddist']<dist_mean+dist_std]

# %%
#df_less=df_less.reset_index().drop(['index'],axis=1)

# %%
#df_less

# %%
#Result = df_less.sort_values('Cluster').groupby(['Cluster'],as_index=False).apply(lambda x: x.sample(1)) ## picking 1 out of each cluster having mean+std/2 < centroid

# %%
#Result = Result.reset_index().drop(['level_0','level_1'],axis=1)

# %%
#Result

# %%
#df_more = df[df['sqddist']>df['sqddist'].mean()+df['sqddist'].std()/2]

# %%
#df_more

# %%
#Result = Result.append(df_more)

# %%
#Result=Result.reset_index().drop(['index'],axis=1)

# %%
##Result

# %%
#Final = Result.drop_duplicates()

# %% [markdown]
#  Cluster Similarity

# %%
df_sorted=df.sort_values(by='Cluster').reset_index()
df_sorted.drop(['index'],axis=1,inplace=True)

# %%
df_sorted.head()
# Out:
#           Newspaper                                            Heading  \
# 0    Indian Express  JEE Advanced 2019: Follow these last minute ti...
# 1  Hindiustan Times  UPSC civil services 2019 prelims on June 2: Re...
# 2  Hindiustan Times  UPSC civil services 2019 prelims on June 2: Re...
# 3  Hindiustan Times  Government- aided Sanskrit colleges facing acu...
# 4  Hindiustan Times  WBCHSE 12th Result 2019: Where and how to chec...
#
#          Date        Time                                                URL  \
# 0  2019-05-26  2:21:15 pm  https://indianexpress.com/article/education/je...
# 1  2019-05-26    09:12:00  https://www.hindustantimes.com/education/upsc-...
# 2  2019-05-26    09:12:00  https://www.hindustantimes.com/education/upsc-...
# 3  2019-05-26    15:18:00  https://www.hindustantimes.com/education/gover...
# 4  2019-05-26    15:08:00  https://www.hindustantimes.com/education/wbchs...
#
#    Cluster  sqddist
# 0        0    21.90
# 1        0    21.68
# 2        0    21.68
# 3        0    22.33
# 4        1    20.61

# %%
vectorizer = TfidfVectorizer()

# %%
grp = df.sort_values('Cluster').groupby(['Cluster'],as_index=False)

# %%
cluster_similarity_value =[]
def cluster_similarity(cluster):
    cluster_heading=cluster['Heading']
    cluster_matrix = vectorizer.fit_transform(cluster_heading)
    cluster_dist = cosine_similarity(cluster_matrix)
    cluster_elements_count = pd.DataFrame.count(cluster)
    #print(cluster_elements_count[0])
    
    x=[]
    for i in cluster_dist:
        #z=(i.sum()-1)/cluster_elements_count
        if((cluster_elements_count[0]-1)==0):
            y=1
        else:
            y=float("{0:.2f}".format(((i.sum())/(cluster_elements_count[0]))))
        x.append(y)
        cluster_similarity_value.append(y)
    print(x)
        
    print()
    print()

# %%
for i in range(n_score):
    cluster_similarity(grp.get_group(i))
# Out:
# [0.35, 0.55, 0.55, 0.25]
#
#
# [0.81, 0.62, 0.81]
#
#
# [0.59, 0.59]
#
#
# [0.51, 0.41, 0.51]
#
#
# [0.25, 0.43, 0.24, 0.34, 0.43, 0.24]
#
#
# [0.63, 0.63]
#
#
# [0.54, 0.56, 0.49]
#
#
# [0.61, 0.61]
#
#
# [0.76, 0.76]
#
#
# [0.37, 0.41, 0.4, 0.28]
#
#
# [1]
#
#
# [0.61, 0.61]
#
#
# [0.53, 0.53]
#
#
# [0.44, 0.42, 0.52]
#
#
# [0.52, 0.52]

# %%
df_sorted['cluster_similarity_value']=cluster_similarity_value

# %%
mean = df_sorted['cluster_similarity_value'].mean()

# %%
df_less_similar=df_sorted[df_sorted['cluster_similarity_value']<mean]

# %%
df_more_similar = df_sorted[df_sorted['cluster_similarity_value']>=mean]

# %%
Result = df_more_similar.sort_values('Cluster').groupby(['Cluster'],as_index=False).apply(lambda x: x.sample(1)) ## picking 1 out of each cluster having mean+std/2 < centroid 
Result.head()
# Out:
#              Newspaper                                            Heading  \
# 0 1   Hindiustan Times  UPSC civil services 2019 prelims on June 2: Re...
# 1 4   Hindiustan Times  WBCHSE 12th Result 2019: Where and how to chec...
# 2 8      Time of India  JEE Advanced 2019 exam tomorrow; check importa...
# 3 19    Indian Express  AMU admissions 2019: Over 16,000 appeared for ...
# 4 20    Indian Express  WBCHSE West Bengal Board 12th result 2019 date...
#
#             Date        Time  \
# 0 1   2019-05-26    09:12:00
# 1 4   2019-05-26    15:08:00
# 2 8   2019-05-26    22:07:00
# 3 19  2019-05-26  8:27:30 pm
# 4 20  2019-05-26  5:23:39 pm
#
#                                                     URL  Cluster  sqddist  \
# 0 1   https://www.hindustantimes.com/education/upsc-...        0    21.68
# 1 4   https://www.hindustantimes.com/education/wbchs...        1    20.61
# 2 8   https://timesofindia.indiatimes.com/home/educa...        2    21.31
# 3 19  https://indianexpress.com/article/education/am...        5    21.64
# 4 20  https://indianexpress.com/article/education/we...        6    21.21
#
#       cluster_similarity_value
# 0 1                       0.55
# 1 4                       0.81
# 2 8                       0.59
# 3 19                      0.63
# 4 20                      0.54

# %%
Result = Result.reset_index().drop(['level_0','level_1'],axis=1)
Result
# Out:
#            Newspaper                                            Heading  \
# 0   Hindiustan Times  UPSC civil services 2019 prelims on June 2: Re...
# 1   Hindiustan Times  WBCHSE 12th Result 2019: Where and how to chec...
# 2      Time of India  JEE Advanced 2019 exam tomorrow; check importa...
# 3     Indian Express  AMU admissions 2019: Over 16,000 appeared for ...
# 4     Indian Express  WBCHSE West Bengal Board 12th result 2019 date...
# 5      Time of India  AIIMS UG 2019 exam concludes; know how many ma...
# 6     Indian Express  WBJEE 2019 today: Things to carry to exam hall...
# 7   Hindiustan Times  Mumbra’s kids get the reading bug from ‘suitca...
# 8     Indian Express  Gujarat Board GSEB 12th Result 2019: 3% jump i...
# 9     Indian Express  Gujarat Board Result 2019: She quit after Clas...
# 10    Indian Express  Navodaya Vidyalaya JNV Class 6 entrance exam r...
# 11  Hindiustan Times  Dubai-based Indian boy finalist in Google Scie...
#
#           Date         Time  \
# 0   2019-05-26     09:12:00
# 1   2019-05-26     15:08:00
# 2   2019-05-26     22:07:00
# 3   2019-05-26   8:27:30 pm
# 4   2019-05-26   5:23:39 pm
# 5   2019-05-26     19:16:00
# 6   2019-05-26  11:28:04 am
# 7   2019-05-26     15:29:00
# 8   2019-05-26  12:22:27 am
# 9                       0.51
# 10                      0.41
# 11                      0.51
# 12                      0.25
# 13                      0.43
# 14                      0.24
# 15                      0.34
# 16                      0.43
# 17                      0.24
# 22                      0.49
# 27                      0.37
# 28                      0.41
# 29                      0.40
# 30                      0.28
# 36                      0.44
# 37                      0.42

# %%
Result = Result.sort_values(by='Cluster')

# %%
Result=Result.reset_index().drop(['index'],axis=1)

# %%
Result
# Out:
#            Newspaper                                            Heading  \
# 0   Hindiustan Times  UPSC civil services 2019 prelims on June 2: Re...
# 1   Hindiustan Times  Government- aided Sanskrit colleges facing acu...
# 2     Indian Express  JEE Advanced 2019: Follow these last minute ti...
# 3   Hindiustan Times  WBCHSE 12th Result 2019: Where and how to chec...
# 4      Time of India  JEE Advanced 2019 exam tomorrow; check importa...
# 5     Indian Express  Mumbai University B.Com third year result 2019...
# 6     Indian Express  DBRAU result declared for MA courses: Check ho...
# 7      Time of India  Mumbai University B.Com 3rd year 2019 results ...
# 8   Hindiustan Times  NTA UGC- NET admit card 2019  to release tomor...
# 9      Time of India  HSSC releases exam schedule for instructor pos...
# 10     Time of India  TN TET Hall Ticket 2019 released @trb.tn.nic.i...
# 11  Hindiustan Times  SSC CGL Tier 1 admit card 2019 released, here’...
# 12  Hindiustan Times  NTA UGC- NET admit card 2019  to release tomor...
# 13     Time of India  Bihar LRC releases merit list for Amin, Kanoon...
# 14    Indian Express  AMU admissions 2019: Over 16,000 appeared for ...
# 15    Indian Express  WBCHSE West Bengal Board 12th result 2019 date...
# 16    Indian Express  Telangana TS intermediate re-evaluation result...
# 17     Time of India  AIIMS UG 2019 exam concludes; know how many ma...
# 18    Indian Express  WBJEE 2019 today: Things to carry to exam hall...
# 19  Hindiustan Times  SSC SI in Delhi Police, CAPF, ASI in CISF Resu...
# 20     Time of India  SSC CPO 2019 result for Paper I announced; che...
# 21    Indian Express  CLAT 2019: Check section-wise paper analysis, ...
# 22     Time of India  CLAT Exam Analysis 2019: Paper Easier than Las...
# 23  Hindiustan Times  Mumbra’s kids get the reading bug from ‘suitca...
# 24    Indian Express  Gujarat Board GSEB 12th Result 2019: 3% jump i...
# 25    Indian Express  Gujarat Board Result 2019: She quit after Clas...
# 26    Indian Express  Navodaya Vidyalaya JNV Class 6 entrance exam r...
# 27  Hindiustan Times  Navodaya Vidyalaya NVS JNVST class 6th result ...
# 28    Indian Express  DU admissions 2019: Application forms tomorrow...
# 29  Hindiustan Times  Dubai-based Indian boy finalist in Google Scie...
#
#           Date         Time  \
# 0   2019-05-26     09:12:00
# 1   2019-05-26     15:18:00
# 2   2019-05-26   2:21:15 pm
# 3   2019-05-26     15:08:00
# 4   2019-05-26     22:07:00
# 5   2019-05-26   5:22:12 pm
# 6   2019-05-26   5:21:01 pm
# 7   2019-05-26     13:58:00
# 8   2019-05-26     12:24:00
# 9   2019-05-26     18:09:00
# 10  2019-05-26     19:18:00
# 11  2019-05-26     14:01:00
# 12  2019-05-26     12:24:00
# 13  2019-05-26     17:21:00
# 14  2019-05-26   8:27:30 pm
# 15  2019-05-26   5:23:39 pm
# 16  2019-05-26   5:22:52 pm
# 17  2019-05-26     19:16:00
