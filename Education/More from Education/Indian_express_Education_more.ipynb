# %%
import requests
import bs4
import pandas as pd
import os

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
def get_date_time(URL):
    req = requests.get(URL)
    soup_date = bs4.BeautifulSoup(req.text,'lxml')
    temp = soup_date.select(".m-story-meta__credit")
    time_date = temp[0].findAll('span')[-1].text
    x=str.split(time_date)
    date = x[1]+' '+x[2]+' '+x[3]
    time = x[4]+' '+x[5]
    return date,time

# %%
link = 'https://indianexpress.com/section/education/'

# %%
res = requests.get(link)
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
h1 = soup.select('.m-article-featured__title')

# %%
records=[]
h1_newspaper='Indian Express'
h1_heading = h1[0].text
h1_url = h1[0].find('a')['href']
h1_date,h1_time = get_date_time(h1_url)
h1_category = 'nil'

records.append((h1_newspaper,h1_heading,h1_category,h1_date,h1_time,h1_url))

# %%
h2=soup.findAll('h2')

# %%
for record in h2[1:-2]:
    Heading = record.text
    URL = record.find('a')['href']
    Date,Time = get_date_time(URL)
    #Time = get_time(URL)
    Source='Indian Express'
    Category = 'nil'
    records.append((Source,Heading,Category,Date,Time,URL))

# %%
h3=soup.select('.m-article-landing__inner')

# %%
for record in h3:
    content = record.select(".m-article-landing__title")[0]
    datetime = record.time.attrs['datetime']

    Heading = content.text
    URL = content.find('a')['href']
    x=str.split(datetime,' ')
    Date = x[0]
    Time = str.split(x[1],'+')[0]+':00'
    Source = 'Indian Express'
    Category = 'nil'
    records.append((Source,Heading,Category,Date,Time,URL))

# %%
df=pd.DataFrame(records,columns=['Source','Heading','Category','Date','Time','URL'])
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#             Source                                            Heading  \
# 0   Indian Express  CLAT Result 2019 declared: How to check at cla...
# 1   Indian Express  CLAT 2019 result declared at clatconsortiumofn...
# 2   Indian Express  JEE Advanced Result 2019 @jeeadv.ac.in HIGHLIG...
# 3   Indian Express  IIT-JEE Advanced 2019 result declared at josaa...
# 4   Indian Express  JEE Advanced results 2019: HRD Minister, Rajas...
# 5   Indian Express  UGC gets 150 proposals for study on quality of...
# 6   Indian Express  Why did JEE Advanced website remain non-functi...
# 7   Indian Express  Rajasthan University UG results 2019 declared:...
# 8   Indian Express  NEET UG 2019 wrong answer keys: SC agrees to h...
# 9   Indian Express  NEET UG wrong answer key 2019: We are not expe...
# 10  Indian Express  DU admissions: Delhi University’s new admissio...
# 11  Indian Express  TS ICET result 2019 declared: How to check at ...
# 12  Indian Express  JEE Advanced result 2019: Kartikey Gupta secur...
# 13  Indian Express  JEE Advanced 2019: Architecture Aptitude Test ...
# 14  Indian Express              How to check JEE Advanced result 2019
# 15  Indian Express  DU admissions 2019: Over 3 lakh students regis...
#
#    Category       Date         Time  \
# 0       nil 2019-06-14   7:11:59 pm
# 1       nil 2019-06-14   7:11:04 pm
# 2       nil 2019-06-14   7:08:07 pm
# 3       nil 2019-06-14   7:03:53 pm
# 4       nil 2019-06-14  19:03:12:00
# 5       nil 2019-06-14  18:50:44:00
# 6       nil 2019-06-14  18:49:19:00
# 7       nil 2019-06-14  18:48:21:00
# 8       nil 2019-06-14  18:47:58:00
# 9       nil 2019-06-14  18:47:47:00
# 10      nil 2019-06-14  18:26:51:00
# 11      nil 2019-06-14  17:09:02:00
# 12      nil 2019-06-14  17:07:33:00
# 13      nil 2019-06-14  16:56:06:00
# 14      nil 2019-06-14  16:31:33:00
# 15      nil 2019-06-14  15:36:18:00
#
#                                                   URL
# 0   https://indianexpress.com/article/education/cl...
# 1   https://indianexpress.com/article/education/cl...
# 2   https://indianexpress.com/article/education/je...
# 3   https://indianexpress.com/article/education/ii...
# 4   https://indianexpress.com/article/education/je...
# 5   https://indianexpress.com/article/education/ug...
# 6   https://indianexpress.com/article/education/wh...
# 7   https://indianexpress.com/article/education/ra...
# 8   https://indianexpress.com/article/education/ne...
# 9   https://indianexpress.com/article/education/ne...
# 10  https://indianexpress.com/article/education/du...
# 11  https://indianexpress.com/article/education/ma...
# 12  https://indianexpress.com/article/education/je...
# 13  https://indianexpress.com/article/education/je...
# 14  https://indianexpress.com/article/education/ii...
# 15  https://indianexpress.com/article/education/du...

# %%
outname ='IE_education-'+str(Today_date)+'.csv'
root = 'CSV/'
if not os.path.exists(root):
    os.mkdir(root)
date_today= Today_date +'/'
outdir=root+ date_today[:-1]
if not os.path.exists(outdir):
    os.mkdir(outdir)
fullname = os.path.join(outdir, outname)

# %%
df.to_csv(fullname,index=False,encoding='utf-8')
