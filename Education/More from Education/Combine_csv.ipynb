# %%
import os
import glob
import pandas as pd
#os.chdir("C://Users/drago/Documents/GitHub/Summer-Project/Education/More from Education")

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
# %run ./Times_of_India_Education_more.ipynb
# %run ./Hindustan_Times_Education_more.ipynb
# %run ./Indian_Express_Education_more.ipynb
# %run ./India_Today_Education_more.ipynb
# %run ./The_Hindu_Education_more.ipynb
#%run ./India_Times_Entertainment_more.ipynb

# %%
extension = 'csv'
string = 'CSV/'+Today_date+'/*.{}'
all_filenames = [i for i in glob.glob(string.format(extension))]

# %%
all_filenames
# Out:
# ['CSV/2019-06-17\\HT_education-2019-06-17.csv',
#  'CSV/2019-06-17\\IE_education-2019-06-17.csv',
#  'CSV/2019-06-17\\IT_education-2019-06-17.csv',
#  'CSV/2019-06-17\\TH_education-2019-06-17.csv',
#  'CSV/2019-06-17\\TOI_education-2019-06-17.csv']

# %%
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])

# %%
outname ='combined_eeducation-'+str(Today_date)+'.csv'
x=r"C:\Users\drago\Documents\GitHub\Summer-Project\Education\More from Education\Combined CSV\ "
if not os.path.exists(x[:-1]):
    os.mkdir(x[:-1])
#date_today= Today_date +'\ '
outdir=x[:-1]
if not os.path.exists(outdir):
    os.mkdir(outdir)
fullname = os.path.join(outdir, outname)

# %%
combined_csv.to_csv(fullname, index=False, encoding='utf-8')

# %%
df = pd.read_csv(fullname)

# %%
df['Category'].value_counts()
# Out:
# nil                       66
# exams result news         43
# admission news            43
# board exams               43
# jobs                      43
# entrance exams            43
# government-jobs           24
# news                      24
# jobs-and-careers          24
# grammar-and-vocabulary    24
# worldly-science           24
# study-abroad              24
# tips-and-tricks           24
# notification              24
# sample-papers             24
# colleges                  22
# careers                   22
# schools                   22
# education                 14
# Name: Category, dtype: int64

# %%
def fix_you(x):
    if(x=='jobs'):
        return 'jobs-and-careers'
    elif(x=='education'):
        return 'news'
    elif(x=='nil'):
        return 'news'
    elif(x=='careers'):
        return 'jobs-and-careers'
    else:
        return x

# %%
df['Category']=df['Category'].apply(fix_you)

# %%
df['Category'].value_counts()
# Out:
# news                      104
# jobs-and-careers           89
# entrance exams             43
# exams result news          43
# admission news             43
# board exams                43
# government-jobs            24
# notification               24
# tips-and-tricks            24
# study-abroad               24
# worldly-science            24
# grammar-and-vocabulary     24
# sample-papers              24
# colleges                   22
# schools                    22
# Name: Category, dtype: int64

# %%
df
# Out:
#                Source                                            Heading  \
# 0    Hindiustan Times  ICAR AIEEA 2019 admit card to be released by N...
# 1    Hindiustan Times  UGC move to thwart ‘pay and publish trash’ cul...
# 2    Hindiustan Times  NEST Result 2019 to be declared today at neste...
# 3    Hindiustan Times   Government gives 3-month grant to 28 DU colleges
# 4    Hindiustan Times  Lack of BSc courses in evening colleges disapp...
# 5    Hindiustan Times  Delhi government schools to invite parents for...
# 6    Hindiustan Times  IGNOU to offer Yoga certification course from ...
# 7    Hindiustan Times  Delhi University’s revised admission bulletin ...
# 8    Hindiustan Times  HSSC Junior Engineers Recruitment 2019: 1624 v...
# 9    Hindiustan Times  IBPS RRB Recruitment 2019: Application begins ...
# 10   Hindiustan Times  Private schools still a pipe dream for poor in...
# 11   Hindiustan Times  Yog to be a subject at school level : AYUSH se...
# ...

# %%
outname ='combined_education-'+str(Today_date)+'.csv'
root = 'Combined CSV/'
if not os.path.exists(root):
    os.mkdir(root)
#date_today= Today_date +'\ '
outdir=root
if not os.path.exists(outdir):
    os.mkdir(outdir)
fullname = os.path.join(outdir, outname)

# %%
df.to_csv(fullname, index=False, encoding='utf-8')
