# %%
import requests
import bs4
import pandas as pd
import os

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
def get_date_time(URL):
    req = requests.get(URL)
    soup_date = bs4.BeautifulSoup(req.text,'lxml')
    temp = soup_date.select(".m-story-meta__credit")
    time_date = temp[0].findAll('span')[-1].text
    x=str.split(time_date)
    date = x[1]+' '+x[2]+' '+x[3]
    time = x[4]+' '+x[5]
    return date,time

# %%
link = 'https://indianexpress.com/section/sports/'

# %%
res = requests.get(link)
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
h1 = soup.select('.m-article-featured__title')

# %%
records=[]
h1_newspaper='Indian Express'
h1_heading = h1[0].text
h1_url = h1[0].find('a')['href']
h1_date,h1_time = get_date_time(h1_url)
h1_category = 'nil'

records.append((h1_newspaper,h1_heading,h1_category,h1_date,h1_time,h1_url))

# %%
h2=soup.findAll('h2')

# %%
for record in h2[1:-3]:
    Heading = record.text
    URL = record.find('a')['href']
    Date,Time = get_date_time(URL)
    #Time = get_time(URL)
    Source='Indian Express'
    Category = 'nil'
    records.append((Source,Heading,Category,Date,Time,URL))

# %%
h3=soup.select('.m-article-landing__inner')

# %%
for record in h3:
    content = record.select(".m-article-landing__title")[0]
    datetime = record.time.attrs['datetime']

    Heading = content.text
    URL = content.find('a')['href']
    x=str.split(datetime,' ')
    Date = x[0]
    Time = str.split(x[1],'+')[0]+':00'
    Source = 'Indian Express'
    Category = 'nil'
    records.append((Source,Heading,Category,Date,Time,URL))

# %%
df=pd.DataFrame(records,columns=['Source','Heading','Category','Date','Time','URL'])
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#             Source                                            Heading  \
# 0   Indian Express      LiveEngland vs West Indies Live Cricket Score
# 1   Indian Express  Sachin Tendulkar sues Australian bat manufactu...
# 2   Indian Express             Recovering Shikhar Dhawan hits the gym
# 3   Indian Express  Bumrah has shown massive improvement on the fi...
# 4   Indian Express  LiveEngland vs West Indies Live Cricket Score ...
# 5   Indian Express  Sachin Tendulkar sues Australian bat manufactu...
# 6   Indian Express  John Wright is my favourite coach, a genuine f...
# 7   Indian Express  Sin City suits him: Tyson Fury makes Vegas deb...
# 8   Indian Express  World Cup 2019: New Zealand coach encourages p...
# 9   Indian Express  Watch: Virender Sehwag and Shoaib Akhtar’s bro...
# 10  Indian Express  Toronto Raptors create history with NBA title,...
# 11  Indian Express  World Cup 2019, England vs West Indies Buildup...
# 12  Indian Express  England vs West Indies Live Cricket Streaming ...
# 13  Indian Express  World Cup 2019: Recovering Shikhar Dhawan hits...
# 14  Indian Express  England vs West Indies, Southampton Weather Re...
# 15  Indian Express      World Cup 2019: Points table as it stands now
#
#    Category       Date         Time  \
# 0       nil 2019-06-14   5:02:22 pm
# 1       nil 2019-06-14   4:30:11 pm
# 2       nil 2019-06-14   2:21:45 pm
# 3       nil 2019-06-14  12:59:21 pm
# 4       nil 2019-06-14  16:58:19:00
# 5       nil 2019-06-14  16:30:11:00
# 6       nil 2019-06-14  15:56:54:00
# 7       nil 2019-06-14  15:53:18:00
# 8       nil 2019-06-14  15:43:35:00
# 9       nil 2019-06-14  15:34:23:00
# 10      nil 2019-06-14  15:21:43:00
# 11      nil 2019-06-14  15:08:49:00
# 12      nil 2019-06-14  14:58:45:00
# 13      nil 2019-06-14  14:21:45:00
# 14      nil 2019-06-14  14:21:01:00
# 15      nil 2019-06-14  13:23:26:00
#
#                                                   URL
# 0   https://indianexpress.com/article/sports/crick...
# 1   https://indianexpress.com/article/sports/crick...
# 2   https://indianexpress.com/article/sports/crick...
# 3   https://indianexpress.com/article/sports/crick...
# 4   https://indianexpress.com/article/sports/crick...
# 5   https://indianexpress.com/article/sports/crick...
# 6   https://indianexpress.com/article/sports/crick...
# 7   https://indianexpress.com/article/sports/sport...
# 8   https://indianexpress.com/article/sports/crick...
# 9   https://indianexpress.com/article/sports/india...
# 10  https://indianexpress.com/article/sports/sport...
# 11  https://indianexpress.com/article/sports/crick...
# 12  https://indianexpress.com/article/sports/crick...
# 13  https://indianexpress.com/article/sports/crick...
# 14  https://indianexpress.com/article/sports/crick...
# 15  https://indianexpress.com/article/sports/crick...

# %%
outname ='IE_sports-'+str(Today_date)+'.csv'

root = 'CSV/'
if not os.path.exists(root):
    os.mkdir(root)
date_today= Today_date +'/'
outdir=root+ date_today[:-1]
if not os.path.exists(outdir):
    os.mkdir(outdir)
fullname = os.path.join(outdir, outname)

# %%
df.to_csv(fullname,index=False,encoding='utf-8')
