# %%
import requests
import bs4
import pandas as pd
import os

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
def get_date_time(URL):
    req = requests.get(URL)
    soup_date = bs4.BeautifulSoup(req.text,'lxml')
    temp = soup_date.select(".m-story-meta__credit")
    time_date = temp[0].findAll('span')[-1].text
    x=str.split(time_date)
    date = x[1]+' '+x[2]+' '+x[3]
    time = x[4]+' '+x[5]
    return date,time

# %%
link = 'https://indianexpress.com/section/sports/'

# %%
res = requests.get(link)
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
h1 = soup.select('.m-article-featured__title')

# %%
records=[]
h1_newspaper='Indian Express'
h1_heading = h1[0].text
h1_url = h1[0].find('a')['href']
h1_date,h1_time = get_date_time(h1_url)
h1_category = 'nil'

records.append((h1_newspaper,h1_heading,h1_category,h1_date,h1_time,h1_url))

# %%
h2=soup.findAll('h2')

# %%
for record in h2[1:-3]:
    Heading = record.text
    URL = record.find('a')['href']
    Date,Time = get_date_time(URL)
    #Time = get_time(URL)
    Newspaper='Indian Express'
    Category = 'nil'
    records.append((Newspaper,Heading,Category,Date,Time,URL))

# %%
h3=soup.select('.m-article-landing__inner')

# %%
for record in h3:
    content = record.select(".m-article-landing__title")[0]
    datetime = record.time.attrs['datetime']

    Heading = content.text
    URL = content.find('a')['href']
    x=str.split(datetime,' ')
    Date = x[0]
    Time = str.split(x[1],'+')[0]+':00'
    Newspaper = 'Indian Express'
    Category = 'nil'
    records.append((Newspaper,Heading,Category,Date,Time,URL))

# %%
df=pd.DataFrame(records,columns=['Newspaper','Heading','Category','Date','Time','URL'])
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#          Newspaper                                            Heading  \
# 0   Indian Express               LiveEngland vs Bangladesh live score
# 1   Indian Express  LiveAFG vs NZ: James Neesham puts New Zealand ...
# 2   Indian Express  LiveFrench Open 2019 Women's Final: Ashleigh B...
# 3   Indian Express  Watch: Jason Roy's collision with umpire delay...
# 4   Indian Express  Steve Smith is world’s best batsman in all thr...
# 5   Indian Express  LiveAfghanistan vs New Zealand Live Cricket Sc...
# 6   Indian Express  FIFA Women’s World Cup: Giulia Gwinn wins it a...
# 7   Indian Express  LiveFrench Open 2019 Women’s Final Live Score,...
# 8   Indian Express  Watch: Jofra Archer’s thunderbolt clips the ba...
# 9   Indian Express  You have chosen money over country: Shoaib Akh...
# 10  Indian Express  French Open 2019: Dominic Thiem beats Novak Dj...
# 11  Indian Express  World Cup 2019: Jason Roy’s stunning 153 takes...
# 12  Indian Express  LiveBangladesh vs England Live Cricket Score O...
# 13  Indian Express  Arjun Munda, BVP Rao set to be elected preside...
# 14  Indian Express  India vs Australia: How is the weather at Kenn...
# 15  Indian Express  Preview: India’s tactical test against formida...
#
#    Category       Date         Time  \
# 0       nil 2019-06-08   9:16:18 pm
# 1       nil 2019-06-08   9:09:36 pm
# 2       nil 2019-06-08   9:18:46 pm
# 3       nil 2019-06-08   6:58:01 pm
# 4       nil 2019-06-08  21:14:50:00
# 5       nil 2019-06-08  21:09:36:00
# 6       nil 2019-06-08  21:08:44:00
# 7       nil 2019-06-08  21:08:15:00
# 8       nil 2019-06-08  21:06:15:00
# 9       nil 2019-06-08  21:05:29:00
# 10      nil 2019-06-08  20:58:28:00
# 11      nil 2019-06-08  20:39:00:00
# 12      nil 2019-06-08  20:32:08:00
# 13      nil 2019-06-08  20:22:18:00
# 14      nil 2019-06-08  20:04:13:00
# 15      nil 2019-06-08  19:37:46:00
#
#                                                   URL
# 0   https://indianexpress.com/article/sports/crick...
# 1   https://indianexpress.com/article/sports/crick...
# 2   https://indianexpress.com/article/sports/tenni...
# 3   https://indianexpress.com/article/sports/crick...
# 4   https://indianexpress.com/article/sports/crick...
# 5   https://indianexpress.com/article/sports/crick...
# 6   https://indianexpress.com/article/sports/footb...
# 7   https://indianexpress.com/article/sports/tenni...
# 8   https://indianexpress.com/article/sports/crick...
# 9   https://indianexpress.com/article/sports/crick...
# 10  https://indianexpress.com/article/sports/tenni...
# 11  https://indianexpress.com/article/sports/jason...
# 12  https://indianexpress.com/article/sports/crick...
# 13  https://indianexpress.com/article/sports/sport...
# 14  https://indianexpress.com/article/sports/crick...
# 15  https://indianexpress.com/article/sports/crick...

# %%
outname ='IE_sports-'+str(Today_date)+'.csv'
x=r"C:\Users\drago\Documents\GitHub\Summer-Project\Sports\More from Sports\CSV\ "
if not os.path.exists(x[:-1]):
    os.mkdir(x[:-1])
date_today= Today_date +'\ '
outdir=x[:-1]+ date_today[:-1]
if not os.path.exists(outdir):
    os.mkdir(outdir)
fullname = os.path.join(outdir, outname)

# %%
df.to_csv(fullname,index=False,encoding='utf-8')
