# %%
import os
import glob
import pandas as pd
#os.chdir("C://Users/drago/Documents/GitHub/Summer-Project/Sports/More from Sports")

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
# %run ./Times_of_India_Sports_more.ipynb
# %run ./Hindustan_Times_Sports_more.ipynb
# %run ./Indian_Express_Sports_more.ipynb
# %run ./India_Today_Sports_more.ipynb
# %run ./The_Hindu_Sports.ipynb
#%run ./India_Times_Entertainment_more.ipynb

# %%
extension = 'csv'
string = 'CSV/'+Today_date+'/*.{}'
all_filenames = [i for i in glob.glob(string.format(extension))]

# %%
all_filenames
# Out:
# ['CSV/2019-06-14\\HT_sports-2019-06-14.csv',
#  'CSV/2019-06-14\\IE_sports-2019-06-14.csv',
#  'CSV/2019-06-14\\IT_Sports-2019-06-14.csv',
#  'CSV/2019-06-14\\TH_sports-2019-06-14.csv',
#  'CSV/2019-06-14\\TOI_sports-2019-06-14.csv']

# %%
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])

# %%
outname ='combined_sports-'+str(Today_date)+'.csv'
root = 'Combined CSV/'
if not os.path.exists(root):
    os.mkdir(root)
#date_today= Today_date +'\ '
outdir=root
if not os.path.exists(outdir):
    os.mkdir(outdir)
fullname = os.path.join(outdir, outname)

# %%
combined_csv.to_csv(fullname, index=False, encoding='utf-8')

# %%
df = pd.read_csv(fullname)

# %%
df['Category'].value_counts()
# Out:
# tennis               111
# cricket              109
# football             106
# other                 72
# hockey                59
# athletics             56
# icc wc 2019           25
# snooker/billiards     25
# wrestling             25
# others                25
# cycling               25
# boxing                25
# racing                25
# shooting              25
# golf                  25
# chess                 25
# motorsport            19
# nil                   16
# news                  12
# badminton             12
# other sports          12
# Name: Category, dtype: int64

# %%
def fix_you(x):
    
    if(x=='news'):
        return 'others'
    elif(x=='nil'):
        return 'others'
    elif(x=='other sports'):
        return 'others'
    elif(x=='other'):
        return 'others'
    elif(x=='snooker/billiards'):
        return 'snooker-billiards'
    else:
        return x

# %%
df['Category']=df['Category'].apply(fix_you)

# %%
df['Category'].value_counts()
# Out:
# others               168
# tennis               111
# cricket              109
# football             106
# hockey                59
# athletics             56
# boxing                25
# racing                25
# chess                 25
# golf                  25
# snooker-billiards     25
# cycling               25
# shooting              25
# icc wc 2019           25
# wrestling             25
# Name: Category, dtype: int64

# %%
z = df['Category'].value_counts()
low_z = z.loc[z<=20].index

# %%
def fix_cat2(x):
    if x in low_z:
        return 'others'
    elif(x=='cities'):
        return 'others'
    else:
        return x
    
df['Category']=df['Category'].apply(fix_cat2)

# %%
df
# Out:
#                Source                                            Heading  \
# 0    Hindiustan Times  ICC World Cup 2019: South Africa, Afghanistan ...
# 1    Hindiustan Times  ICC World Cup 2019: Beware of David Warner, he...
# 2    Hindiustan Times  India vs Pakistan, World Cup 2019: Will not be...
# 3    Hindiustan Times  ICC World Cup 2019, South Africa vs Afghanista...
# 4    Hindiustan Times  ICC World Cup 2019: Australia fret on team bal...
# 5    Hindiustan Times  ICC World Cup 2019: Faf Du Plessis urges South...
# 6    Hindiustan Times  ICC World Cup 2019, Australia vs Sri Lanka Liv...
# 7    Hindiustan Times  ICC World Cup 2019, Australia vs Sri Lanka: To...
# 8    Hindiustan Times  ICC World Cup 2019, India vs Pakistan: The Pak...
