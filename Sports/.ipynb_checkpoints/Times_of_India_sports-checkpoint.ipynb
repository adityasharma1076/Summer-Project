# %%
import requests
import bs4
import os

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
def record_date_time(z):
    x=str.split(z.text,',')
    date =x[0]
    time= x[1]+':00'

    return date,time

def record_URL(x):
    y='https://timesofindia.indiatimes.com'
    url = y+x 
    return url

# %%
link ='https://timesofindia.indiatimes.com/education'

# %%
res = requests.get(link)

# %%
soup =bs4.BeautifulSoup(res.text,'lxml')

# %%
toi=soup.select(".cvs_wdt.clearfix")
len(toi)
# Out:
# 7

# %%
records=[]
for record in content:
    try:
        media_content = record.find("span", {"class" : "w_tle"})
        date_time_content = record.find("span", {"class" : "w_bylinec"})
        Heading = media_content.text
        URL= record_URL(media_content.find('a')['href'])
        Date,Time= record_date_time(date_time_content)
        Newspaper = 'Time of India'
    except:
            continue
    records.append((Newspaper,Heading,Date,Time,URL))

# %%
import pandas as pd
df=pd.DataFrame(records,columns=['Newspaper','Heading','Date','Time','URL'])
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#         Newspaper                                            Heading  \
# 0   Time of India  UPPSC exam controller arrested in LT grade pap...
# 1   Time of India  Rajasthan PTET 2019 result declared @ ptet2019...
# 2   Time of India  Workshops and certificate courses for students...
# 3   Time of India       Science Video Production workshop to be held
# 4   Time of India  Bihar D.El.Ed 2019 merit list expected to be r...
# 5   Time of India  CLAT 2019 Answer Key released @ clatconsortium...
# 6   Time of India  NTA NEET UG 2019 Answer Key released; results ...
# 7   Time of India  Uttarakhand Board 10th and 12th results 2019 d...
# 8   Time of India  UBSE Uttarakhand 10th & 12th results announced...
# 9   Time of India  UK Board result 2019: UBSE Uttarakhand 10th & ...
# 10  Time of India  CSJM Kanpur University B.A., B.Sc. result 2019...
# 11  Time of India  Delhi University Admissions 2019: DU announces...
# 12  Time of India  Navodaya Result 2019: NVS Class 6th result and...
# 13  Time of India  HSCAP Kerala: Second allotment result 2019 rel...
# 14  Time of India  Five medical colleges approved by MCI in Telan...
# 15  Time of India  DU admission registration process 2019 to comm...
# 16  Time of India  HPSC paper leak: Rohtak resident Satish Rathi ...
# 17  Time of India               App for Ramadan Kareem 2019 launched
# 18  Time of India  West Bengal CM to decide on reduced summer vac...
#
#          Date       Time                                                URL
# 0  2019-05-30   20:26:00  https://timesofindia.indiatimes.com/home/educa...
# 1  2019-05-30   18:41:00  https://timesofindia.indiatimes.com/home/educa...
# 2  2019-05-30   18:07:00  https://timesofindia.indiatimes.com/home/educa...
# 3  2019-05-30   18:02:00  https://timesofindia.indiatimes.com/home/educa...
# 4  2019-05-30   17:34:00  https://timesofindia.indiatimes.com/home/educa...
# 5  2019-05-30   15:19:00  https://timesofindia.indiatimes.com/home/educa...
# 6  2019-05-30   11:30:00  https://timesofindia.indiatimes.com/home/educa...
# 7  2019-05-30   11:11:00  https://timesofindia.indiatimes.com/home/educa...
# 8  2019-05-30   11:09:00  https://timesofindia.indiatimes.com/home/educa...
# 9  2019-05-30   09:49:00  https://timesofindia.indiatimes.com/home/educa...
# 10 2019-05-30   09:39:00  https://timesofindia.indiatimes.com/home/educa...
# 11 2019-05-30   09:38:00  https://timesofindia.indiatimes.com/home/educa...
# 12 2019-05-30   09:36:00  https://timesofindia.indiatimes.com/home/educa...
# 13 2019-05-30   09:33:00  https://timesofindia.indiatimes.com/home/educa...
# 14 2019-05-29   23:28:00  https://timesofindia.indiatimes.com/home/educa...
# 15 2019-05-29   21:27:00  https://timesofindia.indiatimes.com/home/educa...
# 16 2019-05-29   20:16:00  https://timesofindia.indiatimes.com/home/educa...
# 17 2019-05-29   20:06:00  https://timesofindia.indiatimes.com/home/educa...
# 18 2019-05-29   19:56:00  https://timesofindia.indiatimes.com/home/educa...

# %%
outname ='TOI_education-'+str(Today_date)+'.csv'
x=r"C:\Users\drago\Documents\GitHub\Summer-Project\Education\CSV\ "
date_today= Today_date +'\ '
outdir=x[:-1]+ date_today[:-1]
if not os.path.exists(outdir):
    os.mkdir(outdir)
fullname = os.path.join(outdir, outname)

# %%
df.to_csv(fullname,index=False,encoding='utf-8')
