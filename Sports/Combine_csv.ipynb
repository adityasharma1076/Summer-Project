# %%
import os
import glob
import pandas as pd
os.chdir("C:\\Users\drago\Documents\GitHub\Summer-Project\Sports")

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
# %run ./Times_of_India_sports.ipynb
# %run ./Hindustan_times_sports.ipynb
# %run ./Indian_express_sports.ipynb
# %run ./India_Today_sports.ipynb

# %%
extension = 'csv'
string = 'CSV/'+Today_date+'/*.{}'
all_filenames = [i for i in glob.glob(string.format(extension))]

# %%
all_filenames
# Out:
# ['CSV/2019-06-02\\HT_sports-2019-06-02.csv',
#  'CSV/2019-06-02\\IE_sports-2019-06-02.csv',
#  'CSV/2019-06-02\\IT_sports-2019-06-02.csv',
#  'CSV/2019-06-02\\TOI_sports-2019-06-02.csv']

# %%
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])

# %%
outname ='combined_sports-'+str(Today_date)+'.csv'
x=r"C:\Users\drago\Documents\GitHub\Summer-Project\Sports\Combined CSV\ "
if not os.path.exists(x[:-1]):
    os.mkdir(x[:-1])
#date_today= Today_date +'\ '
outdir=x[:-1]
if not os.path.exists(outdir):
    os.mkdir(outdir)
fullname = os.path.join(outdir, outname)

# %%
combined_csv.to_csv(fullname, index=False, encoding='utf-8')

# %%
pd.read_csv(fullname)
# Out:
#          Newspaper                                            Heading  \
# 0   Indian Express  LiveWorld Cup, SA vs BAN: De Kock run out afte...
# 1   Indian Express  World Cup 2019: Bangladesh register their high...
# 2   Indian Express  Virat Kohli hurts thumb during nets but 'doing...
# 3   Indian Express  Neymar accused of rape, father says player set up
# 4   Indian Express  LiveSouth Africa vs Bangladesh Live Cricket Sc...
# 5   Indian Express  World Cup 2019: Shane Warne picks his dream XI...
# 6   Indian Express  World Cup 2019: Bangladesh register their high...
# 7   Indian Express  Igor Stimac names six newcomers as India leave...
# 8   Indian Express  Neymar accused of rape, father says player set up
# 9   Indian Express  French Open 2019: Johanna Konta first British ...
# 10  Indian Express  French Open 2019: Rohan Bopanna bows out in th...
# 11  Indian Express  World Cup 2019: Shoaib Akhtar, Kevin Pietersen...
# ...
