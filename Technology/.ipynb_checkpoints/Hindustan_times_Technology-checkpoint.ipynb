# %%
import requests
import bs4
import pandas as pd
import os

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
link = 'https://www.hindustantimes.com/tech/'
res = requests.get(link)

# %%
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
content = soup.select('.media-body')

# %%
content[0]
# Out:
# <div class="media-body">
# <div class="media-heading headingfour">
# <a href="https://www.hindustantimes.com/tech/netflix-whitelists-oneplus-7-series-huawei-p30-phones-for-hdr-video-support/story-d4IbCMLlIpo34GB71mbN7K.html">Netflix whitelists OnePlus 7 series, Huawei P30 phones for HDR video support</a>
# </div>
# <p>Netflix has also enrolled Samsung’s latest Galaxy A series and Google’s older generation phones for HD streaming. Check out the complete list.</p>
# <span class="time-dt">May 31, 2019 14:57</span>
# </div>

# %%
content[0].find('a').text
# Out:
# 'Netflix whitelists OnePlus 7 series, Huawei P30 phones for HDR video support'

# %%
content[0].find('a')['href']
# Out:
# 'https://www.hindustantimes.com/tech/netflix-whitelists-oneplus-7-series-huawei-p30-phones-for-hdr-video-support/story-d4IbCMLlIpo34GB71mbN7K.html'

# %%
content[0].find('span').text
# Out:
# 'May 31, 2019 14:57'

# %%
x=str.split(content[0].find('span').text)

# %%
x[3]
# Out:
# '14:57'

# %%
records=[]
for record in content:
    Heading = record.find('a').text
    URL = record.find('a')['href']
    Newspaper = 'Hindiustan Times'
    dt=str.split(record.find('span').text)
    Date = dt[0]+' '+dt[1]+' '+dt[2]
    Time = dt[3]+':00'
    records.append((Newspaper,Heading,Date,Time,URL))

# %%
df=pd.DataFrame(records,columns=['Newspaper','Heading','Date','Time','URL'])
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#            Newspaper                                            Heading  \
# 0   Hindiustan Times  Netflix whitelists OnePlus 7 series, Huawei P3...
# 1   Hindiustan Times  Samsung Galaxy Note 10 to skip 3.5mm headphone...
# 2   Hindiustan Times  Moto Z4 with 48MP camera, Snapdragon 675 SoC l...
# 3   Hindiustan Times  Huawei reinstated in SD Association, cleared t...
# 4   Hindiustan Times  Google Maps to show speed limits, radar locations
# 5   Hindiustan Times  Facebook shareholders challenged Mark Zuckerbe...
# 6   Hindiustan Times  Inflatable angry emoji looms over Facebook ann...
# 7   Hindiustan Times  Tech giants oppose UK proposal to eavesdrop on...
# 8   Hindiustan Times  Xiaomi Redmi Note 7S with 48-megapixel camera ...
# 9   Hindiustan Times  PUBG Mobile 0.13.0 update: Godzilla crossover,...
# 10  Hindiustan Times  Samsung Galaxy M40 India launch: 5 things we k...
# 11  Hindiustan Times      Google to still ‘block’ ad blockers on Chrome
# 12  Hindiustan Times  Xiaomi Redmi K20 Pro 12GB RAM model in the wor...
# 13  Hindiustan Times  Detel launches cheapest LED TV in India, price...
# 14  Hindiustan Times  Alibaba Cloud unveils new products, calls Indi...
# 15  Hindiustan Times  Chinese database leaks 42.5 million records fr...
# 16  Hindiustan Times  Cricket World Cup 2019: Flipkart, Xiaomi launc...
# 17  Hindiustan Times  Huawei launches 5G lab in South Korea, but kee...
# 18  Hindiustan Times  Samsung aims to double online smartphone sales...
# 19  Hindiustan Times    Apple defends App Store amid mounting criticism
# 20  Hindiustan Times  Google bans apps that facilitate sale of marij...
# 21  Hindiustan Times  ‘Alexa, delete everything I said today’: Amazo...
# 22  Hindiustan Times       Snapchat, JioSaavn partner for music sharing
