# %%
import requests
import bs4
import pandas as pd
import os

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
link = 'https://www.indiatimes.com/technology/'

# %%
res = requests.get(link)
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
main = soup.select('.main-container')

# %%
List = main[0].findAll('li')

# %%
main[0].findAll('li')[1]
# Out:
# <li class="parent_section_trending_counter_1"> <figure> <figcaption class="story-caption"> <a class="section-tag" href="https://www.indiatimes.com/technology/news/" title="News"> News </a> <a class="caption" data-card="sponsord" data-id="368337" href="https://www.indiatimes.com/technology/news/peak-indian-jugaad-rs-6-000-android-becomes-rs-1-lakh-iphone-with-just-a-rs-100-sticker-368337.html" onmousedown="ga('send','event' ,'Web Section Page' ,'Technology Section','Top block','https://www.indiatimes.com/technology/news/peak-indian-jugaad-rs-6-000-android-becomes-rs-1-lakh-iphone-with-just-a-rs-100-sticker-368337.html')" title="Peak Indian Jugaad: Rs 6,000 Android Becomes Rs 1 Lakh iPhone With Just A Rs 100 Sticker"> Peak Indian Jugaad: Rs 6,000 Android Becomes Rs 1 Lakh iPhone With Just A Rs 100 Sticker </a> <div> <div class="card-info cf"> <span class="author-info pull-left"> <a href="https://www.indiatimes.com/author/gwyn-d'mello/" title="Gwyn D'Mello"> Gwyn D'Mello </a> </span> <s
# ...

# %%
main[0].findAll('li')[1].find('a',{'class':'caption'})
# Out:
# <a class="caption" data-card="sponsord" data-id="368337" href="https://www.indiatimes.com/technology/news/peak-indian-jugaad-rs-6-000-android-becomes-rs-1-lakh-iphone-with-just-a-rs-100-sticker-368337.html" onmousedown="ga('send','event' ,'Web Section Page' ,'Technology Section','Top block','https://www.indiatimes.com/technology/news/peak-indian-jugaad-rs-6-000-android-becomes-rs-1-lakh-iphone-with-just-a-rs-100-sticker-368337.html')" title="Peak Indian Jugaad: Rs 6,000 Android Becomes Rs 1 Lakh iPhone With Just A Rs 100 Sticker"> Peak Indian Jugaad: Rs 6,000 Android Becomes Rs 1 Lakh iPhone With Just A Rs 100 Sticker </a>

# %%
records = []
for record in List:
    content = record.find('a',{'class':'caption'})
    
    Heading = content.text
    URL = content['href']
    Date = Today_date
    Time = Today_time
    Newspaper='India Times'
    records.append((Newspaper,Heading,Date,Time,URL))

# %%
df=pd.DataFrame(records,columns=['Newspaper','Heading','Date','Time','URL'])
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#       Newspaper                                            Heading       Date  \
# 0   India Times   This Circus Uses Holograms To Show People Can... 2019-06-02
# 1   India Times   Peak Indian Jugaad: Rs 6,000 Android Becomes ... 2019-06-02
# 2   India Times   Scientists Have Found A Way To Remove CO2 Fro... 2019-06-02
# 3   India Times   7 Features Of The Oppo Reno's Camera That May... 2019-06-02
# 4   India Times   We're Throwing Away So Much Plastic Waste, Be... 2019-06-02
# 5   India Times   It's Not Just You: 4G Download Speeds Across ... 2019-06-02
# 6   India Times   Bengaluru Girl Develops AI Tool To Recognise ... 2019-06-02
# 7   India Times   Mackenzie Bezos Has Pledged To Give Half Of H... 2019-06-02
# 8   India Times   Samsung Galaxy Note 10 Won't Have Headphone J... 2019-06-02
# 9   India Times   Scientists Don't Want To Rely On GPS For Navi... 2019-06-02
# 10  India Times   This Is World's Fastest Camera Which Can Shoo... 2019-06-02
# ...

# %%
outname ='InTi_technology-'+str(Today_date)+'.csv'
x=r"C:\Users\drago\Documents\GitHub\Summer-Project\Technology\CSV\ "
if not os.path.exists(x[:-1]):
    os.mkdir(x[:-1])
date_today= Today_date +'\ '
outdir=x[:-1]+ date_today[:-1]
if not os.path.exists(outdir):
    os.mkdir(outdir)
fullname = os.path.join(outdir, outname)

# %%
df.to_csv(fullname,index=False,encoding='utf-8')
