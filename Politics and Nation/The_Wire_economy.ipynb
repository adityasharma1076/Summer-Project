# %%
import os
import glob
import pandas as pd
import warnings
import requests
import bs4

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
def record_date_time(z):
    x = str.split(z)
    if(x[1]=='hours' or x[1]=='hour'):
        date = Today_date
        return date
    elif(x[1]=='minute' or x[1]=='minutes'):
        date = Today_date
        return date
    else:
        date = z +', 2019'
        return date

def record_URL(x):
    y='https://thewire.in'
    url = y+x 
    return url

# %%
link = 'https://thewire.in/category/economy/all'
res = requests.get(link)
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
economy = 'https://thewire.in/category/economy/'

# %%
Links = soup.findAll('span',{'class' :'hide-on-small-only' })[1:]

# %%
records = []
content_all = soup.findAll('div',{'class' : 'card-content'})
for record in content_all:
    main = record.find('div',{'class':'card__title'})
    Heading = main.find('a')['title']
    URL = record_URL(main.find('a')['href'])
    Date= record_date_time(record.find('div',{'class':'card__posted-on'}).text)
    Source = 'The Wire'
    Category = 'economy-politics'
    Time = Today_time
    records.append((Source,Heading,Category,Date,Time,URL))

# %%
for main in Links:
    url = economy+main.find('button').attrs['value']
    res = requests.get(url)
    soup = bs4.BeautifulSoup(res.text,'lxml')
    content = soup.findAll('div',{'class' : 'card-content'})
    for record in content:
        main = record.find('div',{'class':'card__title'})
        Heading = main.find('a')['title']
        URL = record_URL(main.find('a')['href'])
        Date= record_date_time(record.find('div',{'class':'card__posted-on'}).text)
        Source = 'The Wire'
        Category = 'economy-politics'
        Time = Today_time
        records.append((Source,Heading,Category,Date,Time,URL))

# %%
import pandas as pd
df=pd.DataFrame(records,columns=['Source','Heading','Category','Date','Time','URL'])
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#       Source                                            Heading  \
# 0   The Wire  Viral Acharya had Warned of Economic Fires if ...
# 1   The Wire  How the Centre Can Fulfil Its Economic Promise...
# 2   The Wire  RBI Deputy Governor Viral Acharya Resigns 6 Mo...
# 3   The Wire  Farmers’ Body Cautions Govt About Risk of Drou...
# 4   The Wire  What Does the Periodic Labour Force Survey Tel...
# 5   The Wire  Between 2015 and 2018, More Than 12,000 Farmer...
# 6   The Wire  Economic Prosperity Not Necessarily Leading to...
# 7   The Wire  India Likely to Let Budget Deficit Rise as Tax...
# 8   The Wire  India Inc’s Scandals Can Only be Staunched by ...
# 9   The Wire  DRI Accuses Adani Group Firm of Impeding Over-...
# 10  The Wire  Small Study Examines How Cotton Farming Produc...
# 11  The Wire  Exclusive: Nearly 50% of All NPAs Due to Loans...
# 12  The Wire  In a First, Possession of Banned Cotton Seed L...
# 13  The Wire  Kovind: India Will Implement Reforms to Boost ...
# 14  The Wire  Facebook's Cryptocurrency Plans, if Realised, ...
# 15  The Wire  Industrial Corridors Swallow Hundreds of Fish ...
# 16  The Wire  Saudi Arabia's $44 Billion Refinery Plan in In...
# 17  The Wire  Income Tax Dept Publicly Names 24 Defaulters O...
# 18  The Wire  GST Collection Falls to Rs 85,174 Crore in Feb...
# 19  The Wire  Between 2015 and 2018, More Than 12,000 Farmer...
# 20  The Wire  Small Study Examines How Cotton Farming Produc...
# 21  The Wire  In a First, Possession of Banned Cotton Seed L...
# 22  The Wire  Sugarcane Farmers Caught in a Complex Web of N...
