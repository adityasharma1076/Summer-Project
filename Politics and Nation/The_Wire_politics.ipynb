# %%
import os
import glob
import pandas as pd
import warnings
import requests
import bs4

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
def record_date_time(z):
    x = str.split(z)
    if(z=='today'):
        return Today_date
    if(x[1]=='hours' or x[1]=='hour'):
        date = Today_date
        return date
    elif(x[1]=='minute' or x[1]=='minutes'):
        date = Today_date
        return date
    else:
        date = z +', 2019'
        return date

def record_URL(x):
    y='https://thewire.in'
    url = y+x 
    return url

# %%
link = 'https://thewire.in/category/politics/all'
res = requests.get(link)
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
politics = 'https://thewire.in/category/politics/'

# %%
Links = soup.findAll('span',{'class' :'hide-on-small-only' })[1:]

# %%
records = []
content_all = soup.findAll('div',{'class' : 'card-content'})
for record in content_all:
    main = record.find('div',{'class':'card__title'})
    Heading = main.find('a')['title']
    URL = record_URL(main.find('a')['href'])
    Date= record_date_time(record.find('div',{'class':'card__posted-on'}).text)
    Source = 'The Wire'
    Category = 'politics'
    Time = Today_time
    records.append((Source,Heading,Category,Date,Time,URL))

# %%
for main in Links:
    url = politics+main.find('button').attrs['value']
    res = requests.get(url)
    soup = bs4.BeautifulSoup(res.text,'lxml')
    content = soup.findAll('div',{'class' : 'card-content'})
    for record in content:
        main = record.find('div',{'class':'card__title'})
        Heading = main.find('a')['title']
        URL = record_URL(main.find('a')['href'])
        Date= record_date_time(record.find('div',{'class':'card__posted-on'}).text)
        Source = 'The Wire'
        Category = 'politics'
        Time = Today_time
        records.append((Source,Heading,Category,Date,Time,URL))

# %%
import pandas as pd
df=pd.DataFrame(records,columns=['Source','Heading','Category','Date','Time','URL'])
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#        Source                                            Heading  Category  \
# 0    The Wire  BJD MLA Saroj Meher Arrested for Forcing PWD E...  politics
# 1    The Wire  Viral Acharya had Warned of Economic Fires if ...  politics
# 2    The Wire  Mayawati Ends Alliance With SP, Says BSP to Co...  politics
# 3    The Wire  The Centre's Exclusionist View of Conservation...  politics
# 4    The Wire  SC Seeks Responses of Centre, Bihar, UP Govts ...  politics
# 5    The Wire  Listen | Beyond the Headlines with Siddharth V...  politics
# 6    The Wire  DNA Profiling Bill Likely to Come up Before Ca...  politics
# 7    The Wire  Posts for Mayawati's Brother, Nephew Year Afte...  politics
# 8    The Wire  Watch | Here's Why the Triple Talaq Bill Does ...  politics
# 9    The Wire  Two More AES deaths in Muzaffarpur, Toll Rises...  politics
# 10   The Wire  Jharkhand: Man Dies Days After Being Attacked ...  politics
# 11   The Wire  How the Centre Can Fulfil Its Economic Promise...  politics
# 12   The Wire  Modi Needs to Realise What’s Good for the US I...  politics
# 13   The Wire  Watch | Understanding Kashmir: Civil Initiativ...  politics
# 14   The Wire  No Locus Standi: India Rejects US Religious Fr...  politics
# 15   The Wire  Is the End of the Road Near for BJP and JD(U) ...  politics
