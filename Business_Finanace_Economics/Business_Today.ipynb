# %%
import requests
import bs4
import os
import pandas as pd
import numpy as np
import datetime

# %%
import datetime

now = datetime.datetime.now()


Today_time = now.strftime("%H:%M")

Today_date = now.strftime("%Y-%m-%d")

# %%
def record_date_time(z):
    x=str.split(z,',')
    date =x[0]
    time= x[1] +':00'

    return date,time

def record_URL(x):
    y='https://www.businesstoday.in'
    url = y+x 
    return url

# %%
link = 'https://www.businesstoday.in/'
res = requests.get(link)
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
scrape=soup.find('div',{'class' : 'menues'}).findAll('li')

# %%
records = []
for link in scrape[1:]:
    for i in range(1,3):
        url = record_URL(link.find('a')['href'])+'?page='+str(i)
        category = link.find('a').text.lower()
        res = requests.get(url)
        soup = bs4.BeautifulSoup(res.text,'lxml')
        content = soup.findAll('div',{'class':'boxcont'})
        for record in content:
            try:
                Heading = record.attrs['ctitle']
                URL = record_URL(record.attrs['url'])
                Date = Today_date
                Time = Today_time
                Category = category
                Source = 'Business Today'
                records.append((Source,Heading,Category,Date,Time,URL))
            except:
                continue

# %%
import pandas as pd
df=pd.DataFrame(records,columns=['Source','Heading','Category','Date','Time','URL'])
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#              Source                                            Heading  \
# 0    Business Today  RSS affiliate trade union Bharatiya Mazdoor Sa...
# 1    Business Today  Officers Choice highest selling whisky in worl...
# 2    Business Today  Circular economy could create 1.4 crore jobs i...
# 3    Business Today  JP Nadda named BJPs working president, Amit Sh...
# 4    Business Today  No direct flight to come to India, too ill to ...
# 5    Business Today  Vedanta is bullish on Indian crude; Reliance s...
# 6    Business Today  17th Lok Sabha: PM Modi, ministers take oath a...
# 7    Business Today  Govt compulsorily retires 15 senior indirect t...
# 8    Business Today  As strikes end, SC defers hearing on security ...
# 9    Business Today  PNB scam: Declaration of Nirav Modi as fugitiv...
# 10   Business Today  Slowdown Blues: Fitch lowers Indias GDP growth...
# 11   Business Today  Digital payments to more than double to $235.2...
# 12   Business Today  Wave Group Vice Chairman Monty Chadha gets bai...
# 13   Business Today  New Income Tax rules from today; defaulters ca...
# 14   Business Today  ADB approves Infrastructure development projec...
# 15   Business Today  IL&FS case: Independent directors, rating agen...
# 16   Business Today  India, Myanmar armies target militants of nort...
# 17   Business Today  Noose tightens on Swiss account holders; Detai...
# 18   Business Today  PM Modi sets tough target for his govt; vows t...
# 19   Business Today  Tariff war! India imposes higher customs duty ...
# 20   Business Today  Election Commission announces bypolls to six R...
# 21   Business Today  PM Modi invites all party chiefs to discuss on...
# 22   Business Today  CERC allows Power Grid to offer towers to tele...
# 23   Business Today  PM Modi has courage to construct Ram temple: S...
# 24   Business Today  GST council to discuss proposal to levy GST on...
# 25   Business Today  FPIs remain net buyers in June, pour in Rs 11,...
# 26   Business Today  Niti Aayog meet: CMs demand more central funds...
# 27   Business Today  Export sector vital for boosting income and em...
# 28   Business Today  Razorpay gets $75 million from Sequoia India, ...
# 29   Business Today  IndiGo places $20 bn order for jet engines wit...
# ..              ...                                                ...
# 170  Business Today  Equity assets give better returns than other a...
# 171  Business Today  Missing in action: Why Antonov AN-32 is Indias...
# 172  Business Today  Dont cheer for rate cuts! Banks have only tran...
# 173  Business Today  Extinction Rebellion- Its not climate change, ...
# 174  Business Today  Consumers movie habits havent changed at all: ...
# 175  Business Today  How APIs are transforming businesses in India ...
# 176  Business Today  5G mobile services expected to create over $27...
# 177  Business Today  Time for Modi 2.0 to realise grand healthcare ...
# 178  Business Today  Turning portfolio diversification theory upsid...
# 179  Business Today  Bilderberg Conference 2019: What happens in th...
# 180  Business Today  Economic growth by itself not enough; need to ...
